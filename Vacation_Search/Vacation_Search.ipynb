# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Baruun-Urt      MN  46.6806  113.2792     74.89        54
# 1        1  Saint-Philippe      RE -21.3585   55.7679     67.59        84
# 2        2       Busselton      AU -33.6500  115.3333     53.04        72
# 3        3      Kaitangata      NZ -46.2817  169.8464     54.93        80
# 4        4         Ushuaia      AR -54.8000  -68.3000     42.46        49
#
#    Cloudiness  Wind Speed                 Date Current Description
# 0           0        5.79  2021-07-30 01:48:33           clear sky
# 1          96       15.59  2021-07-30 01:48:34          light rain
# 2          92       27.04  2021-07-30 01:48:34     overcast clouds
# 3          92        8.81  2021-07-30 01:48:35     overcast clouds
# 4           0       10.36  2021-07-30 01:48:35           clear sky

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 60
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & 
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0      Baruun-Urt      MN  46.6806  113.2792     74.89        54
# 1         1  Saint-Philippe      RE -21.3585   55.7679     67.59        84
# 6         6       Jamestown      US  42.0970  -79.2353     74.52        83
# 7         7           Asyut      EG  27.1810   31.1837     80.78        25
# 9         9          Albany      US  42.6001  -73.9662     70.66        94
# 11       11        Westport      US  41.1415  -73.3579     73.80        94
# 12       12      Tuscaloosa      US  33.2098  -87.5692     84.25        89
# 13       13        Ulaangom      MN  49.9811   92.0667     66.54        44
# 15       15         Rikitea      PF -23.1203 -134.9692     71.64        76
# 16       16       Caravelas      BR -17.7125  -39.2481     69.64        82
#
#     Cloudiness  Wind Speed                 Date Current Description
# 0            0        5.79  2021-07-30 01:48:33           clear sky
# 1           96       15.59  2021-07-30 01:48:34          light rain
# 6           40        5.57  2021-07-30 01:47:54    scattered clouds
# 7           95        5.28  2021-07-30 01:45:23     overcast clouds
# 9           92        4.68  2021-07-30 01:45:41     overcast clouds
# 11          90        1.01  2021-07-30 01:48:37                mist
# 12           1        0.00  2021-07-30 01:45:41           clear sky
# 13          57        6.71  2021-07-30 01:48:37       broken clouds
# 15           2        3.53  2021-07-30 01:48:38           clear sky
# 16         100       14.72  2021-07-30 01:37:58     overcast clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                394
# City                   394
# Country                393
# Lat                    394
# Lng                    394
# Max Temp               394
# Humidity               394
# Cloudiness             394
# Wind Speed             394
# Date                   394
# Current Description    394
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_df=preferred_cities_df.dropna()

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp Current Description      Lat       Lng  \
# 0       Baruun-Urt      MN     74.89           clear sky  46.6806  113.2792
# 1   Saint-Philippe      RE     67.59          light rain -21.3585   55.7679
# 6        Jamestown      US     74.52    scattered clouds  42.0970  -79.2353
# 7            Asyut      EG     80.78     overcast clouds  27.1810   31.1837
# 9           Albany      US     70.66     overcast clouds  42.6001  -73.9662
# 11        Westport      US     73.80                mist  41.1415  -73.3579
# 12      Tuscaloosa      US     84.25           clear sky  33.2098  -87.5692
# 13        Ulaangom      MN     66.54       broken clouds  49.9811   92.0667
# 15         Rikitea      PF     71.64           clear sky -23.1203 -134.9692
# 16       Caravelas      BR     69.64     overcast clouds -17.7125  -39.2481
#
#    Hotel Name
# 0
# 1
# 6
# 7
# 9
# 11
# 12
# 13
# 15
# 16

# %%
#Set Google Maps API base URL 
maps_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.

for index, city in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = city["Lat"]
    lng = city["Lng"]
    
    params["location"]= f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    
        # 6d. not specified as the Google base URL was specified earlier 
        #(base URL does not change per iteration, just params dictionary)

    # 6e. Make request and retrieve the JSON data from the search. 
   
    hotels = requests.get(maps_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.

    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print(f"Hotel not found... skipping city {city}")
# Out:
# Hotel not found... skipping city City                            Albany
# Country                             US
# Max Temp                         70.66
# Current Description    overcast clouds
# Lat                            42.6001
# Lng                           -73.9662
# Hotel Name
# Name: 9, dtype: object
# Hotel not found... skipping city City                    Saskylakh
# Country                        RU
# Max Temp                     83.1
# Current Description    few clouds
# Lat                       71.9167
# Lng                      114.0833
# Hotel Name
# Name: 77, dtype: object
# Hotel not found... skipping city City                            Xingyi
# Country                             CN
# Max Temp                         68.41
# Current Description    overcast clouds
# Lat                            24.1877
# Lng                            102.817
# Hotel Name
# Name: 121, dtype: object
# Hotel not found... skipping city City                       Camopi
# Country                        GF
# Max Temp                    71.22
# Current Description    few clouds
# Lat                        3.1655
# Lng                      -52.3158
# Hotel Name
# Name: 136, dtype: object
# Hotel not found... skipping city City                              Adrar
# Country                              MR
# Max Temp                           86.4
# Current Description    scattered clouds
# Lat                             20.5022
# Lng                            -10.0711
# Hotel Name
# Name: 141, dtype: object
# Hotel not found... skipping city City                            Marzuq
# Country                             YE
# Max Temp                          76.8
# Current Description    overcast clouds
# Lat                               14.4
# Lng                            46.4667
# Hotel Name
# Name: 142, dtype: object
# Hotel not found... skipping city City                            Baykit
# Country                             RU
# Max Temp                         62.55
# Current Description    overcast clouds
# Lat                              61.67
# Lng                              96.37
# Hotel Name
# Name: 149, dtype: object
# Hotel not found... skipping city City                        Yangambi
# Country                           CD
# Max Temp                       70.97
# Current Description    broken clouds
# Lat                           0.8102
# Lng                          24.4336
# Hotel Name
# Name: 154, dtype: object
# Hotel not found... skipping city City                         Mongoumba
# Country                             CF
# Max Temp                         73.94
# Current Description    overcast clouds
# Lat                             3.6415
# Lng                            18.5936
# Hotel Name
# Name: 157, dtype: object
# Hotel not found... skipping city City                       Kysyl-Syr
# Country                           RU
# Max Temp                       74.68
# Current Description    broken clouds
# Lat                          63.8986
# Lng                         122.7617
# Hotel Name
# Name: 173, dtype: object
# Hotel not found... skipping city City                      Tadine
# Country                       NC
# Max Temp                   75.25
# Current Description    clear sky
# Lat                       -21.55
# Lng                     167.8833
# Hotel Name
# Name: 178, dtype: object
# Hotel not found... skipping city City                             Wagar
# Country                             SD
# Max Temp                         81.43
# Current Description    overcast clouds
# Lat                            16.1525
# Lng                            36.2032
# Hotel Name
# Name: 181, dtype: object
# Hotel not found... skipping city City                             Gamba
# Country                             GA
# Max Temp                         73.81
# Current Description    overcast clouds
# Lat                              -2.65
# Lng                               10.0
# Hotel Name
# Name: 190, dtype: object
# Hotel not found... skipping city City                            Lisala
# Country                             CD
# Max Temp                         73.38
# Current Description    overcast clouds
# Lat                               2.15
# Lng                            21.5167
# Hotel Name
# Name: 220, dtype: object
# Hotel not found... skipping city City                              Lodja
# Country                              CD
# Max Temp                          68.23
# Current Description    scattered clouds
# Lat                             -3.4833
# Lng                             23.4333
# Hotel Name
# Name: 221, dtype: object
# Hotel not found... skipping city City                               Ler
# Country                             SS
# Max Temp                         71.29
# Current Description    overcast clouds
# Lat                             8.3018
# Lng                            30.1418
# Hotel Name
# Name: 228, dtype: object
# Hotel not found... skipping city City                       Avera
# Country                       US
# Max Temp                   88.72
# Current Description    clear sky
# Lat                       33.194
# Lng                     -82.5271
# Hotel Name
# Name: 233, dtype: object
# Hotel not found... skipping city City                   Yerbogachen
# Country                         RU
# Max Temp                     73.83
# Current Description      clear sky
# Lat                        61.2767
# Lng                       108.0108
# Hotel Name
# Name: 243, dtype: object
# Hotel not found... skipping city City                   Verkhoyansk
# Country                         RU
# Max Temp                     67.03
# Current Description     few clouds
# Lat                        67.5447
# Lng                        133.385
# Hotel Name
# Name: 262, dtype: object
# Hotel not found... skipping city City                        Pirovskoye
# Country                             RU
# Max Temp                         65.66
# Current Description    overcast clouds
# Lat                            57.6267
# Lng                            92.2658
# Hotel Name
# Name: 271, dtype: object
# Hotel not found... skipping city City                           Tessalit
# Country                              ML
# Max Temp                          85.84
# Current Description    scattered clouds
# Lat                             20.1986
# Lng                              1.0114
# Hotel Name
# Name: 293, dtype: object
# Hotel not found... skipping city City                      Bukama
# Country                       CD
# Max Temp                   67.14
# Current Description    clear sky
# Lat                         -9.2
# Lng                        25.85
# Hotel Name
# Name: 303, dtype: object
# Hotel not found... skipping city City                        Vorobyevka
# Country                             RU
# Max Temp                         69.22
# Current Description    overcast clouds
# Lat                            50.6451
# Lng                            40.9245
# Hotel Name
# Name: 311, dtype: object
# Hotel not found... skipping city City                          Issoudun
# Country                             FR
# Max Temp                         60.49
# Current Description    overcast clouds
# Lat                               47.0
# Lng                             1.8333
# Hotel Name
# Name: 319, dtype: object
# Hotel not found... skipping city City                         Goundam
# Country                           ML
# Max Temp                       88.92
# Current Description    broken clouds
# Lat                          16.4145
# Lng                          -3.6708
# Hotel Name
# Name: 328, dtype: object
# Hotel not found... skipping city City                              Rafai
# Country                              CF
# Max Temp                          66.94
# Current Description    scattered clouds
# Lat                                4.95
# Lng                             23.9167
# Hotel Name
# Name: 332, dtype: object
# Hotel not found... skipping city City                       Yumen
# Country                       CN
# Max Temp                   85.21
# Current Description    clear sky
# Lat                      40.2833
# Lng                         97.2
# Hotel Name
# Name: 354, dtype: object
# Hotel not found... skipping city City                             Katete
# Country                              UG
# Max Temp                           61.0
# Current Description    scattered clouds
# Lat                             -0.7818
# Lng                             29.7544
# Hotel Name
# Name: 380, dtype: object
# Hotel not found... skipping city City                        Jurm
# Country                       AF
# Max Temp                    73.0
# Current Description    clear sky
# Lat                      36.8648
# Lng                      70.8342
# Hotel Name
# Name: 416, dtype: object
# Hotel not found... skipping city City                              Amapa
# Country                              BR
# Max Temp                          71.08
# Current Description    scattered clouds
# Lat                                 1.0
# Lng                               -52.0
# Hotel Name
# Name: 421, dtype: object
# Hotel not found... skipping city City                             Nioro
# Country                             GM
# Max Temp                         76.33
# Current Description    overcast clouds
# Lat                              13.35
# Lng                             -15.75
# Hotel Name
# Name: 424, dtype: object
# Hotel not found... skipping city City                         Siguiri
# Country                           GN
# Max Temp                       71.22
# Current Description    moderate rain
# Lat                          11.6667
# Lng                             -9.5
# Hotel Name
# Name: 447, dtype: object
# Hotel not found... skipping city City                              Yaan
# Country                             NG
# Max Temp                         71.17
# Current Description    overcast clouds
# Lat                             7.3833
# Lng                             8.5667
# Hotel Name
# Name: 474, dtype: object
# Hotel not found... skipping city City                   Aleksandrovka
# Country                           UA
# Max Temp                       74.14
# Current Description    broken clouds
# Lat                          46.8383
# Lng                          32.7612
# Hotel Name
# Name: 475, dtype: object
# Hotel not found... skipping city City                            Teya
# Country                           RU
# Max Temp                       61.74
# Current Description    broken clouds
# Lat                          60.3778
# Lng                          92.6267
# Hotel Name
# Name: 489, dtype: object
# Hotel not found... skipping city City                            Mitu
# Country                           CO
# Max Temp                       70.34
# Current Description    broken clouds
# Lat                           1.1983
# Lng                         -70.1733
# Hotel Name
# Name: 491, dtype: object
# Hotel not found... skipping city City                    Malchevskaya
# Country                           RU
# Max Temp                       68.74
# Current Description    broken clouds
# Lat                          49.0552
# Lng                          40.3625
# Hotel Name
# Name: 516, dtype: object
# Hotel not found... skipping city City                   Berdigestyakh
# Country                           RU
# Max Temp                       71.35
# Current Description        clear sky
# Lat                          62.0989
# Lng                         126.6992
# Hotel Name
# Name: 525, dtype: object
# Hotel not found... skipping city City                      Izoplit
# Country                        RU
# Max Temp                    61.97
# Current Description    light rain
# Lat                       56.6256
# Lng                        36.222
# Hotel Name
# Name: 528, dtype: object
# Hotel not found... skipping city City                            Mukhen
# Country                             RU
# Max Temp                          79.7
# Current Description    overcast clouds
# Lat                               48.1
# Lng                              136.1
# Hotel Name
# Name: 529, dtype: object
# Hotel not found... skipping city City                    Vanavara
# Country                       RU
# Max Temp                   76.12
# Current Description    clear sky
# Lat                        60.34
# Lng                     102.2797
# Hotel Name
# Name: 536, dtype: object
# Hotel not found... skipping city City                   Batagay-Alyta
# Country                           RU
# Max Temp                       65.37
# Current Description        clear sky
# Lat                          67.8006
# Lng                         130.4114
# Hotel Name
# Name: 539, dtype: object
# Hotel not found... skipping city City                            Okhotsk
# Country                              RU
# Max Temp                          62.65
# Current Description    scattered clouds
# Lat                             59.3833
# Lng                               143.3
# Hotel Name
# Name: 547, dtype: object

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df=hotel_df.dropna()

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
