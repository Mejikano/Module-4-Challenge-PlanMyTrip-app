# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests

#importing citypy (Installed in PythonData environment)
from citipy import citipy
#importing OpenWeatherMap API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
#Zip the tuple 
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
cities
# Out:
# ['east london',
#  'rikitea',
#  'punta arenas',
#  'te anau',
#  'tsihombe',
#  'albany',
#  'maracas',
#  'naze',
#  'katsiveli',
#  'bredasdorp',
#  'imeni poliny osipenko',
#  'castro',
#  'ushuaia',
#  'duluth',
#  'corrente',
#  'si bun ruang',
#  'grand river south east',
#  'severo-kurilsk',
#  'bluff',
#  'port alfred',
#  'new norfolk',
#  'makushino',
#  'taolanaro',
#  'atuona',
#  'hobart',
#  'bardiyah',
#  'jiuquan',
#  'teknaf',
#  'fort saint john',
#  'tongliao',
#  'micheweni',
#  'saldanha',
#  'umm lajj',
#  'tasiilaq',
#  'chokurdakh',
#  'khatanga',
#  'norman wells',
#  'carnarvon',
#  'kapaa',
#  'hermanus',
#  'bodden town',
#  'lasa',
#  'barentsburg',
#  'okhotsk',
#  'geraldton',
#  'mataura',
#  'vardo',
#  'saskylakh',
#  'tuktoyaktuk',
#  'mizdah',
#  'attawapiskat',
#  'husavik',
#  'finschhafen',
#  'bousso',
#  'talas',
#  'mahebourg',
#  'tarrafal',
#  'severnoye',
#  'dzhebariki-khaya',
#  'illoqqortoormiut',
#  'ribeira grande',
#  'breves',
#  'kungurtug',
#  'vaini',
#  'nata',
#  'nikolskoye',
#  'murgab',
#  'bathsheba',
#  'eyl',
#  'rungata',
#  'srivardhan',
#  'codrington',
#  'revda',
#  'nizhneyansk',
#  'puerto baquerizo moreno',
#  'tessalit',
#  'sahrak',
#  'svetlogorsk',
#  'bengkulu',
#  'cape town',
#  'hilo',
#  'dikson',
#  'sovetskiy',
#  'samusu',
#  'provideniya',
#  'tazovskiy',
#  'mys shmidta',
#  'port lincoln',
#  'jamestown',
#  'hasaki',
#  'old town',
#  'dukat',
#  'kyren',
#  'butaritari',
#  'narsaq',
#  'busselton',
#  'matara',
#  'paamiut',
#  'beira',
#  'broome',
#  'atar',
#  'cherskiy',
#  'tawnat',
#  'romitan',
#  'mitsamiouli',
#  'yatou',
#  'lapas',
#  'hithadhoo',
#  'guia de isora',
#  'sayyan',
#  'san cristobal',
#  'georgetown',
#  'avarua',
#  'alugan',
#  'taltal',
#  'longyearbyen',
#  'los llanos de aridane',
#  'soligalich',
#  'warqla',
#  'natal',
#  'lagos',
#  'amudalavalasa',
#  'dunedin',
#  'sola',
#  'dayong',
#  'yellowknife',
#  'sosnovo-ozerskoye',
#  'zhoucheng',
#  'lokomotivnyy',
#  'arman',
#  'toging',
#  'kodiak',
#  'cidreira',
#  'khani',
#  'vaitupu',
#  'acapulco',
#  'haines junction',
#  'sibolga',
#  'upernavik',
#  'ron',
#  'pittsburg',
#  'saint anthony',
#  'berlevag',
#  'ngukurr',
#  'poya',
#  'totskoye',
#  'sataua',
#  'airai',
#  'itaituba',
#  'asyut',
#  'umzimvubu',
#  'moulmeingyun',
#  'ulladulla',
#  'saint-philippe',
#  'santa cruz de la palma',
#  'nanning',
#  'eregli',
#  'sitka',
#  'bolungarvik',
#  'eureka',
#  'dingle',
#  'belaya gora',
#  'avera',
#  'aflu',
#  'lebu',
#  'tevriz',
#  'samarai',
#  'verkhoyansk',
#  'fortuna',
#  'guanica',
#  'chuy',
#  'santiago',
#  'mweka',
#  'solec kujawski',
#  'podyuga',
#  'torbay',
#  'babayurt',
#  'mormugao',
#  'cockburn town',
#  'qaanaaq',
#  'navsari',
#  'nicoya',
#  'ugoofaaru',
#  'chifeng',
#  'mantua',
#  'gillette',
#  'sibut',
#  'belushya guba',
#  'barrow',
#  'mar del plata',
#  'bambous virieux',
#  'la ronge',
#  'pirot',
#  'opuwo',
#  'padang',
#  'broken hill',
#  'salalah',
#  'puerto ayora',
#  'adre',
#  'thompson',
#  'leningradskiy',
#  'doka',
#  'mount gambier',
#  'tabiauea',
#  'tucuma',
#  'temaraia',
#  'rio grande',
#  'matanza',
#  'laguna',
#  'alyangula',
#  'saint george',
#  'lolua',
#  'preobrazheniye',
#  'ketchikan',
#  'neiafu',
#  'mangan',
#  'porangatu',
#  'savonlinna',
#  'deputatskiy',
#  'panjakent',
#  'dali',
#  'muros',
#  'sao raimundo nonato',
#  'maniitsoq',
#  'ayan',
#  'lompoc',
#  'tezu',
#  'katsuura',
#  'vestmannaeyjar',
#  'palu',
#  'tocopilla',
#  'komsomolskiy',
#  'hoa binh',
#  'constitucion',
#  'kenai',
#  'sorsk',
#  'san vicente',
#  'assai',
#  'staryy nadym',
#  'itarema',
#  'arraial do cabo',
#  'tiksi',
#  'krasnodon',
#  'ostrovnoy',
#  'sobolevo',
#  'yuncheng',
#  'skagastrond',
#  'kutum',
#  'northam',
#  'anadyr',
#  'manta',
#  'marcona',
#  'brae',
#  'luderitz',
#  'fremont',
#  'kamenskoye',
#  'svobodnyy',
#  'knysna',
#  'namatanai',
#  'iqaluit',
#  'belyy yar',
#  'bairiki',
#  'isangel',
#  'gushi',
#  'san rafael',
#  'cayenne',
#  'hambantota',
#  'san carlos de bariloche',
#  'adrar',
#  'presidente dutra',
#  'comodoro rivadavia',
#  'lata',
#  'catabola',
#  'zyryanka',
#  'mahajanga',
#  'hobyo',
#  'sentyabrskiy',
#  'ambilobe',
#  'santa fe',
#  'zhigansk',
#  'dera din panah',
#  'clyde river',
#  'fukue',
#  'arlit',
#  'lorengau',
#  'genhe',
#  'soyo',
#  'medicine hat',
#  'kerki',
#  'olafsvik',
#  'hirara',
#  'colares',
#  'sao joao da barra',
#  'mount isa',
#  'huarmey',
#  'concepcion del oro',
#  'muisne',
#  'jiddah',
#  'port blair',
#  'beringovskiy',
#  'mabaruma',
#  'dueville',
#  'umm durman',
#  'phangnga',
#  'phuket',
#  'nelson bay',
#  'zapolyarnyy',
#  'guerrero negro',
#  'talnakh',
#  'hamilton',
#  'moiyabana',
#  'raga',
#  'mto wa mbu',
#  'den helder',
#  'pangnirtung',
#  'nanortalik',
#  'hervey bay',
#  'ponta do sol',
#  'bethel',
#  'amot',
#  'port hedland',
#  'ahipara',
#  'kahului',
#  'kurumkan',
#  'bafq',
#  'port dickson',
#  'faanui',
#  'gat',
#  'shiozawa',
#  'taoudenni',
#  'amderma',
#  'hay river',
#  'kavieng',
#  'alice springs',
#  'praya',
#  'tungor',
#  'korla',
#  'saint leonard',
#  'flagstaff',
#  'ritchie',
#  'andijon',
#  'gamba',
#  'kompaniyivka',
#  'paraiso',
#  'asau',
#  'casper',
#  'faya',
#  'coquimbo',
#  'zlobin',
#  'montes altos',
#  'tuatapere',
#  'burns lake',
#  'gorin',
#  'yian',
#  'impfondo',
#  'otradnoye',
#  'erenhot',
#  'am timan',
#  'taksimo',
#  'shirgaon',
#  'verkhnetulomskiy',
#  'khromtau',
#  'nome',
#  'sedelnikovo',
#  'suez',
#  'dinsor',
#  'saint-cyr-sur-loire',
#  'victoria',
#  'kailua',
#  'buin',
#  'kaitangata',
#  'buchanan',
#  'passo de camaragibe',
#  'port moresby',
#  'kudahuvadhoo',
#  'caravelas',
#  'weligama',
#  'surovikino',
#  'san joaquin',
#  'vila franca do campo',
#  'ijaki',
#  'tortoli',
#  'tual',
#  'loreto',
#  'ilulissat',
#  'kiunga',
#  'wulanhaote',
#  'garden city',
#  'aksu',
#  'magole',
#  'kangaatsiaq',
#  'strezhevoy',
#  'calvinia',
#  'vila velha',
#  'havoysund',
#  'taebla',
#  'marfino',
#  'sorland',
#  'lincoln',
#  'namtsy',
#  'sistranda',
#  'tautira',
#  'chara',
#  'petropavlovsk-kamchatskiy',
#  'rjukan',
#  'souillac',
#  'camacha',
#  'sioux lookout',
#  'flers',
#  'mlonggo',
#  'pochutla',
#  'rock sound',
#  'camopi',
#  'maruko',
#  'harper',
#  'zeya',
#  'axim',
#  'mrirt',
#  'danville',
#  'ancud',
#  'kenitra',
#  'hami',
#  'manthani',
#  'santa branca',
#  'nalut',
#  'banda aceh',
#  'wexford',
#  'ituni',
#  'kondinskoye',
#  'marsh harbour',
#  'valparaiso',
#  'nouadhibou',
#  'auburn',
#  'librazhd',
#  'riviere-au-renard',
#  'dudinka',
#  'seoul',
#  'aripuana',
#  'alappuzha',
#  'morondava',
#  'mazagao',
#  'xining',
#  'yulara',
#  'oum hadjer',
#  'toppenish',
#  'oistins',
#  'kruisfontein',
#  'phan thiet',
#  'mago',
#  'balkhash',
#  'esperance',
#  'falkoping',
#  'tutoia',
#  'kijang',
#  'kavaratti',
#  'ixtapa',
#  'george',
#  'woodward',
#  'coxim',
#  'leh',
#  'khandyga',
#  'jasper',
#  'zonguldak',
#  'dhanera',
#  'ponta delgada',
#  'charters towers',
#  'kralendijk',
#  'imeni sverdlova',
#  'sterling',
#  'cosoleacaque',
#  'cabo san lucas',
#  'lekoni',
#  'bunia',
#  'acajutla',
#  'antofagasta',
#  'vao',
#  'saleaula',
#  'neuquen',
#  'oussouye',
#  'bubaque',
#  'mpulungu',
#  'sturgis',
#  'texarkana',
#  'san patricio',
#  'utran',
#  'batemans bay',
#  'pevek',
#  'inuvik',
#  'ibra',
#  'carutapera',
#  'sinnamary',
#  'the valley',
#  'hoopstad',
#  'derzhavinsk',
#  'mountrath',
#  'kathu',
#  'luis correia',
#  'rocha',
#  'vilhena',
#  'shenzhen',
#  'weyburn',
#  'mandalgovi',
#  'saint-augustin',
#  'namibe',
#  'sisimiut',
#  'yar-sale',
#  'srednekolymsk',
#  'tiznit',
#  'kendari',
#  'beroroha',
#  'camana',
#  'shihezi',
#  'meyungs',
#  'coihaique',
#  'gongzhuling',
#  'naryan-mar',
#  'sorong',
#  'kargasok',
#  'pontes e lacerda',
#  'gardanne',
#  'port hardy',
#  'tarko-sale',
#  'saint-georges',
#  'thinadhoo',
#  'houston',
#  'buala',
#  'port-cartier',
#  'caohai',
#  'port elizabeth',
#  'novoagansk',
#  'viedma',
#  'havelock',
#  'valdivia',
#  'arcoverde',
#  'mehriz',
#  'bandarbeyla',
#  'moanda',
#  'olga',
#  'necochea',
#  'poum',
#  'cam ranh',
#  'vestmanna',
#  'lyubim',
#  'halalo',
#  'tanete',
#  'oktyabrskoye',
#  'lobva',
#  'moyo',
#  'henties bay',
#  'bonthe',
#  'brigg',
#  'angoram',
#  'yabassi',
#  'moose factory',
#  'sao filipe',
#  'yumen',
#  'kulhudhuffushi',
#  'mapimi',
#  'tumsar',
#  'bambanglipuro',
#  'itacoatiara',
#  'ust-kamchatsk',
#  'tsiroanomandidy',
#  'mugur-aksy',
#  'fevralsk',
#  'ilebo',
#  'la mira',
#  'savelugu',
#  'vrangel',
#  'columbia',
#  'naantali',
#  'baykit',
#  'lebork',
#  'monrovia',
#  'iwanai',
#  'kununurra',
#  'pechenga',
#  'fort nelson',
#  'great yarmouth',
#  'palana',
#  'baillif',
#  'chesma',
#  'samalaeulu',
#  'dhidhdhoo',
#  'haibowan',
#  'tacuati',
#  'zinder',
#  'xam nua',
#  'najran',
#  'saint-joseph',
#  'governador dix-sept rosado',
#  'takoradi',
#  'asfi',
#  'filadelfia',
#  'vostok',
#  'neepawa',
#  'manicore',
#  'yuyao',
#  'pemba',
#  'smithers',
#  'hovd',
#  'egvekinot',
#  'smidovich',
#  'atbasar',
#  'nabire',
#  'pisco',
#  'noyabrsk',
#  'hadejia',
#  'burica',
#  'andilamena',
#  'kuryk',
#  'holme',
#  'coahuayana',
#  'mahibadhoo',
#  'vanimo',
#  'kroya',
#  'marrakesh',
#  'lavrentiya',
#  'yomitan',
#  'gravdal',
#  'andenes',
#  'oak ridge',
#  'madang',
#  'carbonia',
#  'harindanga',
#  'stornoway',
#  'zaplyusye',
#  'waingapu',
#  'aklavik',
#  'ostersund',
#  'fort-shevchenko',
#  'belmonte',
#  'fengrun',
#  'sligo',
#  'makinsk',
#  'krasnousolskiy',
#  'kantunilkin',
#  'diamantino',
#  'karamea',
#  'whitehorse',
#  'tongchuan',
#  'kurilsk',
#  'ossora',
#  'port antonio',
#  'pedro escobedo',
#  'dolbeau',
#  'mundo nuevo',
#  'muana',
#  'lebanon',
#  'haliyal',
#  'margate',
#  'sechura',
#  'dubbo',
#  'ghanzi',
#  'hudson bay',
#  'alofi',
#  'ligayan',
#  'phan rang',
#  'roald',
#  'gornyye klyuchi',
#  'san policarpo',
#  'ajdabiya',
#  'praia da vitoria',
#  'hualmay',
#  'dunkwa',
#  'merauke',
#  'jaleswar',
#  'karratha',
#  'hoquiam',
#  'xuddur',
#  'kampot',
#  'bontang',
#  'quatre cocos',
#  'paita',
#  'oktyabrskiy',
#  'bolshaya murta',
#  'deer lake',
#  'mercedes',
#  'senneterre',
#  'iturama',
#  'flin flon',
#  'oberstdorf',
#  'oranjemund',
#  'okato',
#  'saryshagan',
#  'owosso',
#  'cap malheureux',
#  'roma',
#  'mariakani',
#  'barnala',
#  'moses lake',
#  'villiers',
#  'palmer',
#  'las margaritas',
#  'sochi',
#  'altamont',
#  'bilibino',
#  'dawson creek',
#  'terralba',
#  'porto novo',
#  'laguitas',
#  'yinchuan',
#  'iracoubo',
#  'noumea',
#  'finnsnes',
#  'tarudant',
#  'laiagam',
#  'inirida',
#  'baghdad',
#  'astoria',
#  'buzmeyin',
#  'tonota',
#  'kieta',
#  'omsukchan',
#  'businga',
#  'besikduzu',
#  'aljustrel',
#  'talcahuano',
#  'kobyzhcha',
#  'peoria',
#  'petilia policastro',
#  'acari',
#  'bahia blanca',
#  'atocha',
#  'kharp',
#  'ballina',
#  'college',
#  'evensk',
#  'luau',
#  'kirkuk',
#  'stoyba',
#  'fairbanks',
#  'chor',
#  'mookane',
#  'amzya',
#  'grand centre',
#  'sawtell']

# %%
enumerate(cities)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = len(cities)


url="http://api.openweathermap.org/data/2.5/weather"

params={
    "units":"imperial",
    "appid":weather_api_key,
    "q":""
}


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Create endpoint URL with each city.
    params["q"] = city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(url, params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dscr = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date,
                          "Current Description": city_weather_dscr
                         })

# If an error is experienced, skip the city.
    except Exception as inst:
        print("City not found. Skipping..." + str(inst))
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 737 | east london
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'east+london'}
# City not found. Skipping...'coord'
# Processing Record 2 of Set 737 | rikitea
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'rikitea'}
# Processing Record 3 of Set 737 | punta arenas
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'punta+arenas'}
# City not found. Skipping...'coord'
# Processing Record 4 of Set 737 | te anau
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'te+anau'}
# City not found. Skipping...'coord'
# Processing Record 5 of Set 737 | tsihombe
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tsihombe'}
# City not found. Skipping...'coord'
# Processing Record 6 of Set 737 | albany
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'albany'}
# Processing Record 7 of Set 737 | maracas
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'maracas'}
# Processing Record 8 of Set 737 | naze
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'naze'}
# Processing Record 9 of Set 737 | katsiveli
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'katsiveli'}
# City not found. Skipping...'coord'
# Processing Record 10 of Set 737 | bredasdorp
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bredasdorp'}
# Processing Record 11 of Set 737 | imeni poliny osipenko
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'imeni+poliny+osipenko'}
# City not found. Skipping...'coord'
# Processing Record 12 of Set 737 | castro
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'castro'}
# Processing Record 13 of Set 737 | ushuaia
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ushuaia'}
# Processing Record 14 of Set 737 | duluth
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'duluth'}
# Processing Record 15 of Set 737 | corrente
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'corrente'}
# Processing Record 16 of Set 737 | si bun ruang
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'si+bun+ruang'}
# City not found. Skipping...'coord'
# Processing Record 17 of Set 737 | grand river south east
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'grand+river+south+east'}
# City not found. Skipping...'coord'
# Processing Record 18 of Set 737 | severo-kurilsk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'severo-kurilsk'}
# Processing Record 19 of Set 737 | bluff
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bluff'}
# Processing Record 20 of Set 737 | port alfred
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'port+alfred'}
# City not found. Skipping...'coord'
# Processing Record 21 of Set 737 | new norfolk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'new+norfolk'}
# City not found. Skipping...'coord'
# Processing Record 22 of Set 737 | makushino
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'makushino'}
# Processing Record 23 of Set 737 | taolanaro
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'taolanaro'}
# City not found. Skipping...'coord'
# Processing Record 24 of Set 737 | atuona
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'atuona'}
# Processing Record 25 of Set 737 | hobart
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hobart'}
# Processing Record 26 of Set 737 | bardiyah
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bardiyah'}
# Processing Record 27 of Set 737 | jiuquan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'jiuquan'}
# Processing Record 28 of Set 737 | teknaf
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'teknaf'}
# Processing Record 29 of Set 737 | fort saint john
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'fort+saint+john'}
# City not found. Skipping...'coord'
# Processing Record 30 of Set 737 | tongliao
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tongliao'}
# Processing Record 31 of Set 737 | micheweni
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'micheweni'}
# Processing Record 32 of Set 737 | saldanha
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'saldanha'}
# Processing Record 33 of Set 737 | umm lajj
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'umm+lajj'}
# City not found. Skipping...'coord'
# Processing Record 34 of Set 737 | tasiilaq
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tasiilaq'}
# Processing Record 35 of Set 737 | chokurdakh
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'chokurdakh'}
# Processing Record 36 of Set 737 | khatanga
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'khatanga'}
# Processing Record 37 of Set 737 | norman wells
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'norman+wells'}
# City not found. Skipping...'coord'
# Processing Record 38 of Set 737 | carnarvon
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'carnarvon'}
# Processing Record 39 of Set 737 | kapaa
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kapaa'}
# Processing Record 40 of Set 737 | hermanus
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hermanus'}
# Processing Record 41 of Set 737 | bodden town
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bodden+town'}
# City not found. Skipping...'coord'
# Processing Record 42 of Set 737 | lasa
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lasa'}
# Processing Record 43 of Set 737 | barentsburg
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'barentsburg'}
# City not found. Skipping...'coord'
# Processing Record 44 of Set 737 | okhotsk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'okhotsk'}
# Processing Record 45 of Set 737 | geraldton
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'geraldton'}
# Processing Record 46 of Set 737 | mataura
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mataura'}
# Processing Record 47 of Set 737 | vardo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'vardo'}
# Processing Record 48 of Set 737 | saskylakh
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'saskylakh'}
# Processing Record 49 of Set 737 | tuktoyaktuk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tuktoyaktuk'}
# Processing Record 50 of Set 737 | mizdah
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mizdah'}
# Processing Record 51 of Set 737 | attawapiskat
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'attawapiskat'}
# City not found. Skipping...'coord'
# Processing Record 52 of Set 737 | husavik
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'husavik'}
# Processing Record 53 of Set 737 | finschhafen
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'finschhafen'}
# Processing Record 54 of Set 737 | bousso
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bousso'}
# Processing Record 55 of Set 737 | talas
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'talas'}
# Processing Record 56 of Set 737 | mahebourg
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mahebourg'}
# Processing Record 57 of Set 737 | tarrafal
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tarrafal'}
# Processing Record 58 of Set 737 | severnoye
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'severnoye'}
# Processing Record 59 of Set 737 | dzhebariki-khaya
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dzhebariki-khaya'}
# Processing Record 60 of Set 737 | illoqqortoormiut
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'illoqqortoormiut'}
# City not found. Skipping...'coord'
# Processing Record 61 of Set 737 | ribeira grande
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ribeira+grande'}
# City not found. Skipping...'coord'
# Processing Record 62 of Set 737 | breves
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'breves'}
# Processing Record 63 of Set 737 | kungurtug
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kungurtug'}
# Processing Record 64 of Set 737 | vaini
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'vaini'}
# Processing Record 65 of Set 737 | nata
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'nata'}
# Processing Record 66 of Set 737 | nikolskoye
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'nikolskoye'}
# Processing Record 67 of Set 737 | murgab
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'murgab'}
# Processing Record 68 of Set 737 | bathsheba
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bathsheba'}
# Processing Record 69 of Set 737 | eyl
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'eyl'}
# Processing Record 70 of Set 737 | rungata
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'rungata'}
# City not found. Skipping...'coord'
# Processing Record 71 of Set 737 | srivardhan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'srivardhan'}
# Processing Record 72 of Set 737 | codrington
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'codrington'}
# Processing Record 73 of Set 737 | revda
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'revda'}
# Processing Record 74 of Set 737 | nizhneyansk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'nizhneyansk'}
# City not found. Skipping...'coord'
# Processing Record 75 of Set 737 | puerto baquerizo moreno
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'puerto+baquerizo+moreno'}
# City not found. Skipping...'coord'
# Processing Record 76 of Set 737 | tessalit
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tessalit'}
# Processing Record 77 of Set 737 | sahrak
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sahrak'}
# City not found. Skipping...'coord'
# Processing Record 78 of Set 737 | svetlogorsk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'svetlogorsk'}
# Processing Record 79 of Set 737 | bengkulu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bengkulu'}
# Processing Record 80 of Set 737 | cape town
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'cape+town'}
# City not found. Skipping...'coord'
# Processing Record 81 of Set 737 | hilo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hilo'}
# Processing Record 82 of Set 737 | dikson
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dikson'}
# Processing Record 83 of Set 737 | sovetskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sovetskiy'}
# Processing Record 84 of Set 737 | samusu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'samusu'}
# City not found. Skipping...'coord'
# Processing Record 85 of Set 737 | provideniya
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'provideniya'}
# Processing Record 86 of Set 737 | tazovskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tazovskiy'}
# Processing Record 87 of Set 737 | mys shmidta
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mys+shmidta'}
# City not found. Skipping...'coord'
# Processing Record 88 of Set 737 | port lincoln
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'port+lincoln'}
# City not found. Skipping...'coord'
# Processing Record 89 of Set 737 | jamestown
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'jamestown'}
# Processing Record 90 of Set 737 | hasaki
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hasaki'}
# Processing Record 91 of Set 737 | old town
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'old+town'}
# City not found. Skipping...'coord'
# Processing Record 92 of Set 737 | dukat
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dukat'}
# Processing Record 93 of Set 737 | kyren
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kyren'}
# Processing Record 94 of Set 737 | butaritari
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'butaritari'}
# Processing Record 95 of Set 737 | narsaq
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'narsaq'}
# Processing Record 96 of Set 737 | busselton
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'busselton'}
# Processing Record 97 of Set 737 | matara
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'matara'}
# Processing Record 98 of Set 737 | paamiut
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'paamiut'}
# Processing Record 99 of Set 737 | beira
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'beira'}
# Processing Record 100 of Set 737 | broome
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'broome'}
# Processing Record 101 of Set 737 | atar
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'atar'}
# Processing Record 102 of Set 737 | cherskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'cherskiy'}
# Processing Record 103 of Set 737 | tawnat
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tawnat'}
# City not found. Skipping...'coord'
# Processing Record 104 of Set 737 | romitan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'romitan'}
# Processing Record 105 of Set 737 | mitsamiouli
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mitsamiouli'}
# Processing Record 106 of Set 737 | yatou
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'yatou'}
# Processing Record 107 of Set 737 | lapas
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lapas'}
# Processing Record 108 of Set 737 | hithadhoo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hithadhoo'}
# Processing Record 109 of Set 737 | guia de isora
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'guia+de+isora'}
# City not found. Skipping...'coord'
# Processing Record 110 of Set 737 | sayyan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sayyan'}
# Processing Record 111 of Set 737 | san cristobal
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'san+cristobal'}
# City not found. Skipping...'coord'
# Processing Record 112 of Set 737 | georgetown
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'georgetown'}
# Processing Record 113 of Set 737 | avarua
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'avarua'}
# Processing Record 114 of Set 737 | alugan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'alugan'}
# Processing Record 115 of Set 737 | taltal
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'taltal'}
# Processing Record 116 of Set 737 | longyearbyen
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'longyearbyen'}
# Processing Record 117 of Set 737 | los llanos de aridane
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'los+llanos+de+aridane'}
# City not found. Skipping...'coord'
# Processing Record 118 of Set 737 | soligalich
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'soligalich'}
# Processing Record 119 of Set 737 | warqla
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'warqla'}
# City not found. Skipping...'coord'
# Processing Record 120 of Set 737 | natal
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'natal'}
# Processing Record 121 of Set 737 | lagos
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lagos'}
# Processing Record 122 of Set 737 | amudalavalasa
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'amudalavalasa'}
# Processing Record 123 of Set 737 | dunedin
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dunedin'}
# Processing Record 124 of Set 737 | sola
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sola'}
# Processing Record 125 of Set 737 | dayong
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dayong'}
# Processing Record 126 of Set 737 | yellowknife
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'yellowknife'}
# Processing Record 127 of Set 737 | sosnovo-ozerskoye
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sosnovo-ozerskoye'}
# Processing Record 128 of Set 737 | zhoucheng
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'zhoucheng'}
# Processing Record 129 of Set 737 | lokomotivnyy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lokomotivnyy'}
# Processing Record 130 of Set 737 | arman
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'arman'}
# Processing Record 131 of Set 737 | toging
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'toging'}
# City not found. Skipping...'coord'
# Processing Record 132 of Set 737 | kodiak
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kodiak'}
# Processing Record 133 of Set 737 | cidreira
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'cidreira'}
# Processing Record 134 of Set 737 | khani
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'khani'}
# Processing Record 135 of Set 737 | vaitupu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'vaitupu'}
# City not found. Skipping...'coord'
# Processing Record 136 of Set 737 | acapulco
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'acapulco'}
# Processing Record 137 of Set 737 | haines junction
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'haines+junction'}
# City not found. Skipping...'coord'
# Processing Record 138 of Set 737 | sibolga
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sibolga'}
# Processing Record 139 of Set 737 | upernavik
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'upernavik'}
# Processing Record 140 of Set 737 | ron
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ron'}
# Processing Record 141 of Set 737 | pittsburg
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'pittsburg'}
# Processing Record 142 of Set 737 | saint anthony
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'saint+anthony'}
# City not found. Skipping...'coord'
# Processing Record 143 of Set 737 | berlevag
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'berlevag'}
# Processing Record 144 of Set 737 | ngukurr
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ngukurr'}
# City not found. Skipping...'coord'
# Processing Record 145 of Set 737 | poya
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'poya'}
# Processing Record 146 of Set 737 | totskoye
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'totskoye'}
# Processing Record 147 of Set 737 | sataua
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sataua'}
# City not found. Skipping...'coord'
# Processing Record 148 of Set 737 | airai
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'airai'}
# Processing Record 149 of Set 737 | itaituba
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'itaituba'}
# Processing Record 150 of Set 737 | asyut
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'asyut'}
# Processing Record 151 of Set 737 | umzimvubu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'umzimvubu'}
# City not found. Skipping...'coord'
# Processing Record 152 of Set 737 | moulmeingyun
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'moulmeingyun'}
# City not found. Skipping...'coord'
# Processing Record 153 of Set 737 | ulladulla
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ulladulla'}
# Processing Record 154 of Set 737 | saint-philippe
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'saint-philippe'}
# Processing Record 155 of Set 737 | santa cruz de la palma
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'santa+cruz+de+la+palma'}
# City not found. Skipping...'coord'
# Processing Record 156 of Set 737 | nanning
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'nanning'}
# Processing Record 157 of Set 737 | eregli
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'eregli'}
# Processing Record 158 of Set 737 | sitka
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sitka'}
# Processing Record 159 of Set 737 | bolungarvik
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bolungarvik'}
# City not found. Skipping...'coord'
# Processing Record 160 of Set 737 | eureka
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'eureka'}
# Processing Record 161 of Set 737 | dingle
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dingle'}
# Processing Record 162 of Set 737 | belaya gora
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'belaya+gora'}
# City not found. Skipping...'coord'
# Processing Record 163 of Set 737 | avera
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'avera'}
# Processing Record 164 of Set 737 | aflu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'aflu'}
# City not found. Skipping...'coord'
# Processing Record 165 of Set 737 | lebu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lebu'}
# Processing Record 166 of Set 737 | tevriz
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tevriz'}
# Processing Record 167 of Set 737 | samarai
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'samarai'}
# Processing Record 168 of Set 737 | verkhoyansk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'verkhoyansk'}
# Processing Record 169 of Set 737 | fortuna
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'fortuna'}
# Processing Record 170 of Set 737 | guanica
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'guanica'}
# Processing Record 171 of Set 737 | chuy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'chuy'}
# Processing Record 172 of Set 737 | santiago
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'santiago'}
# Processing Record 173 of Set 737 | mweka
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mweka'}
# Processing Record 174 of Set 737 | solec kujawski
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'solec+kujawski'}
# City not found. Skipping...'coord'
# Processing Record 175 of Set 737 | podyuga
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'podyuga'}
# Processing Record 176 of Set 737 | torbay
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'torbay'}
# Processing Record 177 of Set 737 | babayurt
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'babayurt'}
# Processing Record 178 of Set 737 | mormugao
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mormugao'}
# Processing Record 179 of Set 737 | cockburn town
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'cockburn+town'}
# City not found. Skipping...'coord'
# Processing Record 180 of Set 737 | qaanaaq
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'qaanaaq'}
# Processing Record 181 of Set 737 | navsari
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'navsari'}
# Processing Record 182 of Set 737 | nicoya
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'nicoya'}
# Processing Record 183 of Set 737 | ugoofaaru
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ugoofaaru'}
# Processing Record 184 of Set 737 | chifeng
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'chifeng'}
# Processing Record 185 of Set 737 | mantua
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mantua'}
# Processing Record 186 of Set 737 | gillette
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'gillette'}
# Processing Record 187 of Set 737 | sibut
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sibut'}
# Processing Record 188 of Set 737 | belushya guba
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'belushya+guba'}
# City not found. Skipping...'coord'
# Processing Record 189 of Set 737 | barrow
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'barrow'}
# Processing Record 190 of Set 737 | mar del plata
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mar+del+plata'}
# City not found. Skipping...'coord'
# Processing Record 191 of Set 737 | bambous virieux
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bambous+virieux'}
# City not found. Skipping...'coord'
# Processing Record 192 of Set 737 | la ronge
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'la+ronge'}
# City not found. Skipping...'coord'
# Processing Record 193 of Set 737 | pirot
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'pirot'}
# Processing Record 194 of Set 737 | opuwo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'opuwo'}
# Processing Record 195 of Set 737 | padang
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'padang'}
# Processing Record 196 of Set 737 | broken hill
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'broken+hill'}
# City not found. Skipping...'coord'
# Processing Record 197 of Set 737 | salalah
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'salalah'}
# Processing Record 198 of Set 737 | puerto ayora
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'puerto+ayora'}
# City not found. Skipping...'coord'
# Processing Record 199 of Set 737 | adre
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'adre'}
# Processing Record 200 of Set 737 | thompson
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'thompson'}
# Processing Record 201 of Set 737 | leningradskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'leningradskiy'}
# Processing Record 202 of Set 737 | doka
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'doka'}
# Processing Record 203 of Set 737 | mount gambier
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mount+gambier'}
# City not found. Skipping...'coord'
# Processing Record 204 of Set 737 | tabiauea
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tabiauea'}
# City not found. Skipping...'coord'
# Processing Record 205 of Set 737 | tucuma
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tucuma'}
# Processing Record 206 of Set 737 | temaraia
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'temaraia'}
# City not found. Skipping...'coord'
# Processing Record 207 of Set 737 | rio grande
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'rio+grande'}
# City not found. Skipping...'coord'
# Processing Record 208 of Set 737 | matanza
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'matanza'}
# Processing Record 209 of Set 737 | laguna
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'laguna'}
# Processing Record 210 of Set 737 | alyangula
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'alyangula'}
# Processing Record 211 of Set 737 | saint george
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'saint+george'}
# City not found. Skipping...'coord'
# Processing Record 212 of Set 737 | lolua
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lolua'}
# City not found. Skipping...'coord'
# Processing Record 213 of Set 737 | preobrazheniye
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'preobrazheniye'}
# Processing Record 214 of Set 737 | ketchikan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ketchikan'}
# Processing Record 215 of Set 737 | neiafu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'neiafu'}
# Processing Record 216 of Set 737 | mangan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mangan'}
# Processing Record 217 of Set 737 | porangatu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'porangatu'}
# Processing Record 218 of Set 737 | savonlinna
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'savonlinna'}
# Processing Record 219 of Set 737 | deputatskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'deputatskiy'}
# Processing Record 220 of Set 737 | panjakent
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'panjakent'}
# Processing Record 221 of Set 737 | dali
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dali'}
# Processing Record 222 of Set 737 | muros
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'muros'}
# Processing Record 223 of Set 737 | sao raimundo nonato
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sao+raimundo+nonato'}
# City not found. Skipping...'coord'
# Processing Record 224 of Set 737 | maniitsoq
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'maniitsoq'}
# Processing Record 225 of Set 737 | ayan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ayan'}
# Processing Record 226 of Set 737 | lompoc
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lompoc'}
# Processing Record 227 of Set 737 | tezu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tezu'}
# Processing Record 228 of Set 737 | katsuura
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'katsuura'}
# Processing Record 229 of Set 737 | vestmannaeyjar
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'vestmannaeyjar'}
# Processing Record 230 of Set 737 | palu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'palu'}
# Processing Record 231 of Set 737 | tocopilla
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tocopilla'}
# Processing Record 232 of Set 737 | komsomolskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'komsomolskiy'}
# Processing Record 233 of Set 737 | hoa binh
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hoa+binh'}
# City not found. Skipping...'coord'
# Processing Record 234 of Set 737 | constitucion
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'constitucion'}
# Processing Record 235 of Set 737 | kenai
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kenai'}
# Processing Record 236 of Set 737 | sorsk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sorsk'}
# Processing Record 237 of Set 737 | san vicente
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'san+vicente'}
# City not found. Skipping...'coord'
# Processing Record 238 of Set 737 | assai
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'assai'}
# Processing Record 239 of Set 737 | staryy nadym
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'staryy+nadym'}
# City not found. Skipping...'coord'
# Processing Record 240 of Set 737 | itarema
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'itarema'}
# Processing Record 241 of Set 737 | arraial do cabo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'arraial+do+cabo'}
# City not found. Skipping...'coord'
# Processing Record 242 of Set 737 | tiksi
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tiksi'}
# Processing Record 243 of Set 737 | krasnodon
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'krasnodon'}
# Processing Record 244 of Set 737 | ostrovnoy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ostrovnoy'}
# Processing Record 245 of Set 737 | sobolevo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sobolevo'}
# Processing Record 246 of Set 737 | yuncheng
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'yuncheng'}
# Processing Record 247 of Set 737 | skagastrond
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'skagastrond'}
# City not found. Skipping...'coord'
# Processing Record 248 of Set 737 | kutum
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kutum'}
# Processing Record 249 of Set 737 | northam
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'northam'}
# Processing Record 250 of Set 737 | anadyr
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'anadyr'}
# Processing Record 251 of Set 737 | manta
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'manta'}
# Processing Record 252 of Set 737 | marcona
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'marcona'}
# City not found. Skipping...'coord'
# Processing Record 253 of Set 737 | brae
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'brae'}
# Processing Record 254 of Set 737 | luderitz
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'luderitz'}
# Processing Record 255 of Set 737 | fremont
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'fremont'}
# Processing Record 256 of Set 737 | kamenskoye
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kamenskoye'}
# City not found. Skipping...'coord'
# Processing Record 257 of Set 737 | svobodnyy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'svobodnyy'}
# Processing Record 258 of Set 737 | knysna
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'knysna'}
# Processing Record 259 of Set 737 | namatanai
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'namatanai'}
# Processing Record 260 of Set 737 | iqaluit
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'iqaluit'}
# Processing Record 261 of Set 737 | belyy yar
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'belyy+yar'}
# City not found. Skipping...'coord'
# Processing Record 262 of Set 737 | bairiki
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bairiki'}
# Processing Record 263 of Set 737 | isangel
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'isangel'}
# Processing Record 264 of Set 737 | gushi
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'gushi'}
# Processing Record 265 of Set 737 | san rafael
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'san+rafael'}
# City not found. Skipping...'coord'
# Processing Record 266 of Set 737 | cayenne
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'cayenne'}
# Processing Record 267 of Set 737 | hambantota
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hambantota'}
# Processing Record 268 of Set 737 | san carlos de bariloche
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'san+carlos+de+bariloche'}
# City not found. Skipping...'coord'
# Processing Record 269 of Set 737 | adrar
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'adrar'}
# Processing Record 270 of Set 737 | presidente dutra
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'presidente+dutra'}
# City not found. Skipping...'coord'
# Processing Record 271 of Set 737 | comodoro rivadavia
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'comodoro+rivadavia'}
# City not found. Skipping...'coord'
# Processing Record 272 of Set 737 | lata
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lata'}
# Processing Record 273 of Set 737 | catabola
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'catabola'}
# Processing Record 274 of Set 737 | zyryanka
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'zyryanka'}
# Processing Record 275 of Set 737 | mahajanga
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mahajanga'}
# Processing Record 276 of Set 737 | hobyo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hobyo'}
# Processing Record 277 of Set 737 | sentyabrskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sentyabrskiy'}
# City not found. Skipping...'coord'
# Processing Record 278 of Set 737 | ambilobe
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ambilobe'}
# Processing Record 279 of Set 737 | santa fe
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'santa+fe'}
# City not found. Skipping...'coord'
# Processing Record 280 of Set 737 | zhigansk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'zhigansk'}
# Processing Record 281 of Set 737 | dera din panah
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dera+din+panah'}
# City not found. Skipping...'coord'
# Processing Record 282 of Set 737 | clyde river
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'clyde+river'}
# City not found. Skipping...'coord'
# Processing Record 283 of Set 737 | fukue
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'fukue'}
# Processing Record 284 of Set 737 | arlit
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'arlit'}
# Processing Record 285 of Set 737 | lorengau
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lorengau'}
# Processing Record 286 of Set 737 | genhe
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'genhe'}
# Processing Record 287 of Set 737 | soyo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'soyo'}
# Processing Record 288 of Set 737 | medicine hat
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'medicine+hat'}
# City not found. Skipping...'coord'
# Processing Record 289 of Set 737 | kerki
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kerki'}
# City not found. Skipping...'coord'
# Processing Record 290 of Set 737 | olafsvik
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'olafsvik'}
# Processing Record 291 of Set 737 | hirara
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hirara'}
# Processing Record 292 of Set 737 | colares
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'colares'}
# Processing Record 293 of Set 737 | sao joao da barra
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sao+joao+da+barra'}
# City not found. Skipping...'coord'
# Processing Record 294 of Set 737 | mount isa
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mount+isa'}
# City not found. Skipping...'coord'
# Processing Record 295 of Set 737 | huarmey
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'huarmey'}
# Processing Record 296 of Set 737 | concepcion del oro
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'concepcion+del+oro'}
# City not found. Skipping...'coord'
# Processing Record 297 of Set 737 | muisne
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'muisne'}
# Processing Record 298 of Set 737 | jiddah
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'jiddah'}
# City not found. Skipping...'coord'
# Processing Record 299 of Set 737 | port blair
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'port+blair'}
# City not found. Skipping...'coord'
# Processing Record 300 of Set 737 | beringovskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'beringovskiy'}
# Processing Record 301 of Set 737 | mabaruma
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mabaruma'}
# Processing Record 302 of Set 737 | dueville
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dueville'}
# Processing Record 303 of Set 737 | umm durman
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'umm+durman'}
# City not found. Skipping...'coord'
# Processing Record 304 of Set 737 | phangnga
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'phangnga'}
# Processing Record 305 of Set 737 | phuket
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'phuket'}
# Processing Record 306 of Set 737 | nelson bay
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'nelson+bay'}
# City not found. Skipping...'coord'
# Processing Record 307 of Set 737 | zapolyarnyy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'zapolyarnyy'}
# Processing Record 308 of Set 737 | guerrero negro
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'guerrero+negro'}
# City not found. Skipping...'coord'
# Processing Record 309 of Set 737 | talnakh
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'talnakh'}
# Processing Record 310 of Set 737 | hamilton
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hamilton'}
# Processing Record 311 of Set 737 | moiyabana
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'moiyabana'}
# City not found. Skipping...'coord'
# Processing Record 312 of Set 737 | raga
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'raga'}
# Processing Record 313 of Set 737 | mto wa mbu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mto+wa+mbu'}
# City not found. Skipping...'coord'
# Processing Record 314 of Set 737 | den helder
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'den+helder'}
# City not found. Skipping...'coord'
# Processing Record 315 of Set 737 | pangnirtung
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'pangnirtung'}
# Processing Record 316 of Set 737 | nanortalik
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'nanortalik'}
# Processing Record 317 of Set 737 | hervey bay
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hervey+bay'}
# City not found. Skipping...'coord'
# Processing Record 318 of Set 737 | ponta do sol
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ponta+do+sol'}
# City not found. Skipping...'coord'
# Processing Record 319 of Set 737 | bethel
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bethel'}
# Processing Record 320 of Set 737 | amot
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'amot'}
# Processing Record 321 of Set 737 | port hedland
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'port+hedland'}
# City not found. Skipping...'coord'
# Processing Record 322 of Set 737 | ahipara
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ahipara'}
# Processing Record 323 of Set 737 | kahului
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kahului'}
# Processing Record 324 of Set 737 | kurumkan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kurumkan'}
# Processing Record 325 of Set 737 | bafq
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bafq'}
# Processing Record 326 of Set 737 | port dickson
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'port+dickson'}
# City not found. Skipping...'coord'
# Processing Record 327 of Set 737 | faanui
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'faanui'}
# Processing Record 328 of Set 737 | gat
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'gat'}
# Processing Record 329 of Set 737 | shiozawa
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'shiozawa'}
# Processing Record 330 of Set 737 | taoudenni
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'taoudenni'}
# Processing Record 331 of Set 737 | amderma
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'amderma'}
# City not found. Skipping...'coord'
# Processing Record 332 of Set 737 | hay river
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hay+river'}
# City not found. Skipping...'coord'
# Processing Record 333 of Set 737 | kavieng
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kavieng'}
# Processing Record 334 of Set 737 | alice springs
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'alice+springs'}
# City not found. Skipping...'coord'
# Processing Record 335 of Set 737 | praya
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'praya'}
# Processing Record 336 of Set 737 | tungor
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tungor'}
# Processing Record 337 of Set 737 | korla
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'korla'}
# Processing Record 338 of Set 737 | saint leonard
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'saint+leonard'}
# City not found. Skipping...'coord'
# Processing Record 339 of Set 737 | flagstaff
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'flagstaff'}
# Processing Record 340 of Set 737 | ritchie
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ritchie'}
# Processing Record 341 of Set 737 | andijon
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'andijon'}
# Processing Record 342 of Set 737 | gamba
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'gamba'}
# Processing Record 343 of Set 737 | kompaniyivka
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kompaniyivka'}
# Processing Record 344 of Set 737 | paraiso
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'paraiso'}
# Processing Record 345 of Set 737 | asau
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'asau'}
# Processing Record 346 of Set 737 | casper
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'casper'}
# Processing Record 347 of Set 737 | faya
# ...
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'oak+ridge'}
# City not found. Skipping...'coord'
# Processing Record 623 of Set 737 | madang
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'madang'}
# Processing Record 624 of Set 737 | carbonia
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'carbonia'}
# Processing Record 625 of Set 737 | harindanga
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'harindanga'}
# Processing Record 626 of Set 737 | stornoway
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'stornoway'}
# Processing Record 627 of Set 737 | zaplyusye
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'zaplyusye'}
# City not found. Skipping...'coord'
# Processing Record 628 of Set 737 | waingapu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'waingapu'}
# Processing Record 629 of Set 737 | aklavik
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'aklavik'}
# Processing Record 630 of Set 737 | ostersund
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ostersund'}
# Processing Record 631 of Set 737 | fort-shevchenko
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'fort-shevchenko'}
# Processing Record 632 of Set 737 | belmonte
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'belmonte'}
# Processing Record 633 of Set 737 | fengrun
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'fengrun'}
# Processing Record 634 of Set 737 | sligo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sligo'}
# Processing Record 635 of Set 737 | makinsk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'makinsk'}
# Processing Record 636 of Set 737 | krasnousolskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'krasnousolskiy'}
# City not found. Skipping...'coord'
# Processing Record 637 of Set 737 | kantunilkin
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kantunilkin'}
# Processing Record 638 of Set 737 | diamantino
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'diamantino'}
# Processing Record 639 of Set 737 | karamea
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'karamea'}
# City not found. Skipping...'coord'
# Processing Record 640 of Set 737 | whitehorse
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'whitehorse'}
# Processing Record 641 of Set 737 | tongchuan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tongchuan'}
# Processing Record 642 of Set 737 | kurilsk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kurilsk'}
# Processing Record 643 of Set 737 | ossora
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ossora'}
# Processing Record 644 of Set 737 | port antonio
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'port+antonio'}
# City not found. Skipping...'coord'
# Processing Record 645 of Set 737 | pedro escobedo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'pedro+escobedo'}
# City not found. Skipping...'coord'
# Processing Record 646 of Set 737 | dolbeau
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dolbeau'}
# City not found. Skipping...'coord'
# Processing Record 647 of Set 737 | mundo nuevo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mundo+nuevo'}
# City not found. Skipping...'coord'
# Processing Record 648 of Set 737 | muana
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'muana'}
# Processing Record 649 of Set 737 | lebanon
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'lebanon'}
# Processing Record 650 of Set 737 | haliyal
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'haliyal'}
# Processing Record 651 of Set 737 | margate
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'margate'}
# Processing Record 652 of Set 737 | sechura
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sechura'}
# Processing Record 653 of Set 737 | dubbo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dubbo'}
# Processing Record 654 of Set 737 | ghanzi
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ghanzi'}
# Processing Record 655 of Set 737 | hudson bay
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hudson+bay'}
# City not found. Skipping...'coord'
# Processing Record 656 of Set 737 | alofi
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'alofi'}
# Processing Record 657 of Set 737 | ligayan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ligayan'}
# Processing Record 658 of Set 737 | phan rang
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'phan+rang'}
# City not found. Skipping...'coord'
# Processing Record 659 of Set 737 | roald
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'roald'}
# Processing Record 660 of Set 737 | gornyye klyuchi
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'gornyye+klyuchi'}
# City not found. Skipping...'coord'
# Processing Record 661 of Set 737 | san policarpo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'san+policarpo'}
# City not found. Skipping...'coord'
# Processing Record 662 of Set 737 | ajdabiya
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ajdabiya'}
# Processing Record 663 of Set 737 | praia da vitoria
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'praia+da+vitoria'}
# City not found. Skipping...'coord'
# Processing Record 664 of Set 737 | hualmay
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hualmay'}
# Processing Record 665 of Set 737 | dunkwa
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dunkwa'}
# Processing Record 666 of Set 737 | merauke
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'merauke'}
# Processing Record 667 of Set 737 | jaleswar
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'jaleswar'}
# Processing Record 668 of Set 737 | karratha
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'karratha'}
# Processing Record 669 of Set 737 | hoquiam
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'hoquiam'}
# Processing Record 670 of Set 737 | xuddur
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'xuddur'}
# Processing Record 671 of Set 737 | kampot
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kampot'}
# Processing Record 672 of Set 737 | bontang
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bontang'}
# Processing Record 673 of Set 737 | quatre cocos
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'quatre+cocos'}
# City not found. Skipping...'coord'
# Processing Record 674 of Set 737 | paita
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'paita'}
# Processing Record 675 of Set 737 | oktyabrskiy
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'oktyabrskiy'}
# Processing Record 676 of Set 737 | bolshaya murta
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bolshaya+murta'}
# City not found. Skipping...'coord'
# Processing Record 677 of Set 737 | deer lake
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'deer+lake'}
# City not found. Skipping...'coord'
# Processing Record 678 of Set 737 | mercedes
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mercedes'}
# Processing Record 679 of Set 737 | senneterre
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'senneterre'}
# Processing Record 680 of Set 737 | iturama
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'iturama'}
# Processing Record 681 of Set 737 | flin flon
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'flin+flon'}
# City not found. Skipping...'coord'
# Processing Record 682 of Set 737 | oberstdorf
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'oberstdorf'}
# Processing Record 683 of Set 737 | oranjemund
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'oranjemund'}
# Processing Record 684 of Set 737 | okato
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'okato'}
# Processing Record 685 of Set 737 | saryshagan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'saryshagan'}
# City not found. Skipping...'coord'
# Processing Record 686 of Set 737 | owosso
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'owosso'}
# Processing Record 687 of Set 737 | cap malheureux
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'cap+malheureux'}
# City not found. Skipping...'coord'
# Processing Record 688 of Set 737 | roma
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'roma'}
# Processing Record 689 of Set 737 | mariakani
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mariakani'}
# Processing Record 690 of Set 737 | barnala
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'barnala'}
# Processing Record 691 of Set 737 | moses lake
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'moses+lake'}
# City not found. Skipping...'coord'
# Processing Record 692 of Set 737 | villiers
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'villiers'}
# Processing Record 693 of Set 737 | palmer
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'palmer'}
# Processing Record 694 of Set 737 | las margaritas
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'las+margaritas'}
# City not found. Skipping...'coord'
# Processing Record 695 of Set 737 | sochi
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sochi'}
# Processing Record 696 of Set 737 | altamont
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'altamont'}
# Processing Record 697 of Set 737 | bilibino
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bilibino'}
# Processing Record 698 of Set 737 | dawson creek
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'dawson+creek'}
# City not found. Skipping...'coord'
# Processing Record 699 of Set 737 | terralba
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'terralba'}
# Processing Record 700 of Set 737 | porto novo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'porto+novo'}
# City not found. Skipping...'coord'
# Processing Record 701 of Set 737 | laguitas
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'laguitas'}
# Processing Record 702 of Set 737 | yinchuan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'yinchuan'}
# Processing Record 703 of Set 737 | iracoubo
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'iracoubo'}
# Processing Record 704 of Set 737 | noumea
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'noumea'}
# Processing Record 705 of Set 737 | finnsnes
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'finnsnes'}
# Processing Record 706 of Set 737 | tarudant
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tarudant'}
# City not found. Skipping...'coord'
# Processing Record 707 of Set 737 | laiagam
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'laiagam'}
# City not found. Skipping...'coord'
# Processing Record 708 of Set 737 | inirida
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'inirida'}
# Processing Record 709 of Set 737 | baghdad
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'baghdad'}
# Processing Record 710 of Set 737 | astoria
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'astoria'}
# Processing Record 711 of Set 737 | buzmeyin
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'buzmeyin'}
# Processing Record 712 of Set 737 | tonota
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'tonota'}
# Processing Record 713 of Set 737 | kieta
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kieta'}
# Processing Record 714 of Set 737 | omsukchan
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'omsukchan'}
# Processing Record 715 of Set 737 | businga
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'businga'}
# Processing Record 716 of Set 737 | besikduzu
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'besikduzu'}
# Processing Record 717 of Set 737 | aljustrel
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'aljustrel'}
# Processing Record 718 of Set 737 | talcahuano
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'talcahuano'}
# Processing Record 719 of Set 737 | kobyzhcha
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kobyzhcha'}
# Processing Record 720 of Set 737 | peoria
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'peoria'}
# Processing Record 721 of Set 737 | petilia policastro
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'petilia+policastro'}
# City not found. Skipping...'coord'
# Processing Record 722 of Set 737 | acari
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'acari'}
# Processing Record 723 of Set 737 | bahia blanca
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'bahia+blanca'}
# City not found. Skipping...'coord'
# Processing Record 724 of Set 737 | atocha
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'atocha'}
# Processing Record 725 of Set 737 | kharp
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kharp'}
# Processing Record 726 of Set 737 | ballina
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'ballina'}
# Processing Record 727 of Set 737 | college
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'college'}
# Processing Record 728 of Set 737 | evensk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'evensk'}
# Processing Record 729 of Set 737 | luau
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'luau'}
# Processing Record 730 of Set 737 | kirkuk
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'kirkuk'}
# Processing Record 731 of Set 737 | stoyba
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'stoyba'}
# City not found. Skipping...'coord'
# Processing Record 732 of Set 737 | fairbanks
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'fairbanks'}
# Processing Record 733 of Set 737 | chor
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'chor'}
# Processing Record 734 of Set 737 | mookane
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'mookane'}
# Processing Record 735 of Set 737 | amzya
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'amzya'}
# Processing Record 736 of Set 737 | grand centre
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'grand+centre'}
# City not found. Skipping...'coord'
# Processing Record 737 of Set 737 | sawtell
# {'units': 'imperial', 'appid': '421a1ea675f8653e2a7e3b6652490ae7', 'q': 'sawtell'}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea -23.1203 -134.9692     71.64        76           2
# 1          Albany  42.6001  -73.9662     70.66        94          92
# 2         Maracas -13.4411  -40.4308     64.54        76           1
# 3            Naze  28.3667  129.4833     85.12        78         100
# 4      Bredasdorp -34.5322   20.0403     47.52        87          12
# 5          Castro -24.7911  -50.0119     33.82        60           0
# 6         Ushuaia -54.8000  -68.3000     42.46        49           0
# 7          Duluth  46.7833  -92.1066     73.98        56           1
# 8        Corrente  -3.7367  -43.3394     73.96        89          54
# 9  Severo-Kurilsk  50.6789  156.1250     62.35        87          93
#
#    Wind Speed Country                 Date Current Description
# 0        3.53      PF  2021-07-30 01:34:05           clear sky
# 1        4.68      US  2021-07-30 01:37:05     overcast clouds
# 2        7.47      BR  2021-07-30 01:37:19           clear sky
# 3        1.34      JP  2021-07-30 01:37:20     overcast clouds
# 4        5.75      ZA  2021-07-30 01:37:20          few clouds
# 5        2.82      BR  2021-07-30 01:37:20           clear sky
# 6       10.36      AR  2021-07-30 01:37:21           clear sky
# 7        8.05      US  2021-07-30 01:37:21           clear sky
# 8        4.25      BR  2021-07-30 01:37:21       broken clouds
# 9        4.05      RU  2021-07-30 01:37:22     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
