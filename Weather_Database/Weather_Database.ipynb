# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests

#importing citypy (Installed in PythonData environment)
from citipy import citipy
#importing OpenWeatherMap API key
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
#Zip the tuple 
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
cities
# Out:
# ['ponta do sol',
#  'baruun-urt',
#  'belyy yar',
#  'cape town',
#  'saint-philippe',
#  'bambous virieux',
#  'hay river',
#  'busselton',
#  'kaitangata',
#  'ushuaia',
#  'haines junction',
#  'clyde river',
#  'punta arenas',
#  'constitucion',
#  'sao filipe',
#  'jamestown',
#  'asyut',
#  'esperance',
#  'albany',
#  'castro',
#  'westport',
#  'tuscaloosa',
#  'ulaangom',
#  'waitati',
#  'rikitea',
#  'caravelas',
#  'beringovskiy',
#  'belushya guba',
#  'salalah',
#  'illoqqortoormiut',
#  'lyaskelya',
#  'port elizabeth',
#  'hobart',
#  'taolanaro',
#  'mahanoro',
#  'bredasdorp',
#  'bargur',
#  'bonthe',
#  'tasiilaq',
#  'barrow',
#  'vila velha',
#  'mar del plata',
#  'lolua',
#  'hilo',
#  'bafra',
#  'sibolga',
#  'victoria',
#  'kalmunai',
#  'dikson',
#  'yaring',
#  'vaini',
#  'graaff-reinet',
#  'luau',
#  'khatanga',
#  'hami',
#  'manzhouli',
#  'dashitou',
#  'tiksi',
#  'nanakuli',
#  'chuy',
#  'muros',
#  'katsuura',
#  'san quintin',
#  'pangnirtung',
#  'mys shmidta',
#  'plettenberg bay',
#  'batagay',
#  'kapaa',
#  'marcona',
#  'hermanus',
#  'hithadhoo',
#  'bathsheba',
#  'port lincoln',
#  'bilma',
#  'cabo san lucas',
#  'arraial do cabo',
#  'half moon bay',
#  'itaituba',
#  'qaqortoq',
#  'petauke',
#  'tuatapere',
#  'monroe',
#  'georgetown',
#  'bikin',
#  'grindavik',
#  'port alfred',
#  'butaritari',
#  'nuuk',
#  'eyl',
#  'chokurdakh',
#  'mataura',
#  'auki',
#  'nikolskoye',
#  'arona',
#  'yellowknife',
#  'tuktoyaktuk',
#  'katherine',
#  'vardo',
#  'srednekolymsk',
#  'bambanglipuro',
#  'invermere',
#  'lompoc',
#  'saskylakh',
#  'santiago del estero',
#  'amderma',
#  'iqaluit',
#  'itarema',
#  'zyryanka',
#  'sorong',
#  'kalianget',
#  'buin',
#  'severo-kurilsk',
#  'avarua',
#  'ribeira grande',
#  'souillac',
#  'edd',
#  'vaitupu',
#  'provideniya',
#  'port macquarie',
#  'evensk',
#  'brawley',
#  'upernavik',
#  'aguimes',
#  'barentsburg',
#  'rio grande',
#  'udachnyy',
#  'carnarvon',
#  'mackenzie',
#  'bengkulu',
#  'canutama',
#  'cockburn town',
#  'banjar',
#  'atuona',
#  'dong xoai',
#  'luderitz',
#  'skreia',
#  'nueva loja',
#  'deer lake',
#  'san patricio',
#  'mahebourg',
#  'mehamn',
#  'dossor',
#  'anadyr',
#  'najran',
#  'bethel',
#  'east london',
#  'husavik',
#  'vallenar',
#  'carmarthen',
#  'kodiak',
#  'nanortalik',
#  'gravdal',
#  'thompson',
#  'gazanjyk',
#  'athabasca',
#  'rexburg',
#  'axim',
#  'malkangiri',
#  'henties bay',
#  'doha',
#  'xingyi',
#  'guerrero negro',
#  'goderich',
#  'vila franca do campo',
#  'ilulissat',
#  'paradwip',
#  'kloulklubed',
#  'marrakesh',
#  'linjiang',
#  'isla vista',
#  'umzimvubu',
#  'berlevag',
#  'kyra',
#  'buala',
#  'samarai',
#  'port hawkesbury',
#  'tomohon',
#  'seydi',
#  'aden',
#  'aksu',
#  'faanui',
#  'camopi',
#  'coihaique',
#  'sao domingos',
#  'leh',
#  'yalvac',
#  'asau',
#  'adrar',
#  'marzuq',
#  'cranbrook',
#  'airai',
#  'matara',
#  'aswan',
#  'colgong',
#  'grand gaube',
#  'geraldton',
#  'tsihombe',
#  'baykit',
#  'gornopravdinsk',
#  'mount gambier',
#  'jumla',
#  'ahipara',
#  'ahuimanu',
#  'yangambi',
#  'minot',
#  'presidencia roque saenz pena',
#  'cam ranh',
#  'sambava',
#  'mongoumba',
#  'pucallpa',
#  'lao cai',
#  'puerto ayora',
#  'pisco',
#  'surt',
#  'namibe',
#  'torbay',
#  'nguiu',
#  'carutapera',
#  'saleaula',
#  'agirish',
#  'cayenne',
#  'palmer',
#  'marakkanam',
#  'kununurra',
#  'elat',
#  'cherskiy',
#  'harper',
#  'deputatskiy',
#  'kysyl-syr',
#  'san ignacio',
#  'slavutych',
#  'bluff',
#  'kilindoni',
#  'morant bay',
#  'jackson',
#  'tadine',
#  'aksarka',
#  'alihe',
#  'norman wells',
#  'wagar',
#  'omsukchan',
#  'ambovombe',
#  'gainesville',
#  'huehuetan',
#  'qaanaaq',
#  'ola',
#  'zhigansk',
#  'ondorhaan',
#  'naze',
#  'guia de isora',
#  'hare bay',
#  'gamba',
#  'esso',
#  'falealupo',
#  'ust-kulom',
#  'aklavik',
#  'korostyshiv',
#  'krasnoselkup',
#  'rena',
#  'lagoa',
#  'new norfolk',
#  'quatre cocos',
#  'conde',
#  'talara',
#  'ambilobe',
#  'ambalavao',
#  'chapais',
#  'bundaberg',
#  'maniitsoq',
#  'san cristobal',
#  'kavieng',
#  'bowen',
#  'calvinia',
#  'flin flon',
#  'fukuchiyama',
#  'lebu',
#  'tumannyy',
#  'huntington',
#  'bridlington',
#  'sur',
#  'bayan',
#  'aubenas',
#  'bayanday',
#  'codrington',
#  'iskateley',
#  'lima',
#  'seeboden',
#  'lisala',
#  'lodja',
#  'el cobre',
#  'arlit',
#  'jalu',
#  'alice springs',
#  'attawapiskat',
#  'bargal',
#  'bonavista',
#  'uhlove',
#  'mongo',
#  'mount isa',
#  'morondava',
#  'ler',
#  'cabo rojo',
#  'vao',
#  'sisimiut',
#  'biak',
#  'porosozero',
#  'avera',
#  'kushima',
#  'dunedin',
#  'texarkana',
#  'antalaha',
#  'aloleng',
#  'vreed en hoop',
#  'am timan',
#  'palabuhanratu',
#  'artyk',
#  'karkaralinsk',
#  'petropavlovsk-kamchatskiy',
#  'yataity',
#  'gujan-mestras',
#  'kavaratti',
#  'yerbogachen',
#  'yulara',
#  'mudgee',
#  'touros',
#  'korhogo',
#  'julio de castilhos',
#  'padang',
#  'acarau',
#  'shingu',
#  'janakpur road',
#  'kuche',
#  'kozhevnikovo',
#  'carbonia',
#  'atar',
#  'chirongui',
#  'bukit rambai',
#  'green valley',
#  'eureka',
#  'hamilton',
#  'houma',
#  'quang ngai',
#  'el sauzal',
#  'hasaki',
#  'villamontes',
#  'ranong',
#  'luang prabang',
#  'komsomolskiy',
#  'verkhoyansk',
#  'qeshm',
#  'ketchikan',
#  'kruisfontein',
#  'nizhniy kuranakh',
#  'charleston',
#  'tommot',
#  'fairbanks',
#  'allapalli',
#  'royan',
#  'pirovskoye',
#  'saurimo',
#  'lorengau',
#  'saldanha',
#  'coquimbo',
#  'bacuit',
#  'nemuro',
#  'arimalam',
#  'umm durman',
#  'kanniyakumari',
#  'bougouni',
#  'pishin',
#  'pailon',
#  'sirjan',
#  'warqla',
#  'dumas',
#  'rungata',
#  'magadan',
#  'madeji',
#  'nome',
#  'neenah',
#  'fukuma',
#  'uromi',
#  'cidreira',
#  'grande prairie',
#  'acapulco',
#  'narsaq',
#  'tessalit',
#  'severobaykalsk',
#  'jambi',
#  'fairlie',
#  'la ronge',
#  'rodrigues alves',
#  'ixtapa',
#  'huilong',
#  'varkkallai',
#  'ostrovnoy',
#  'buraydah',
#  'constantine',
#  'bukama',
#  'kirakira',
#  'kommunar',
#  'necochea',
#  'sukumo',
#  'sorland',
#  'longyearbyen',
#  'karratha',
#  'vorobyevka',
#  'bandar-e torkaman',
#  'novoagansk',
#  'valparaiso',
#  'phalaborwa',
#  'igarka',
#  'fortuna',
#  'tahoua',
#  'west wendover',
#  'asfi',
#  'issoudun',
#  'xining',
#  'lyubar',
#  'klamath falls',
#  'tugalan',
#  'natal',
#  'sentyabrskiy',
#  'siocon',
#  'buchanan',
#  'tezu',
#  'olafsvik',
#  'waipawa',
#  'goundam',
#  'kokopo',
#  'mitsamiouli',
#  'skibbereen',
#  'nizhneyansk',
#  'walvis bay',
#  'rafai',
#  'sao joao da barra',
#  'samusu',
#  'vangaindrano',
#  'isangel',
#  'santa vitoria do palmar',
#  'sitka',
#  'potgietersrus',
#  'ugoofaaru',
#  'santarem',
#  'pasni',
#  'pimenteiras',
#  'paamiut',
#  'taoudenni',
#  'seinajoki',
#  'pevek',
#  'hofn',
#  'farkhor',
#  'otane',
#  'griffith',
#  'wasilla',
#  'aksehir',
#  'richards bay',
#  'dali',
#  'sechura',
#  'strezhevoy',
#  'sandy bay',
#  'pangkalanbuun',
#  'port hedland',
#  'yumen',
#  'grand river south east',
#  'talbahat',
#  'flinders',
#  'sapele',
#  'tuggurt',
#  'pangody',
#  'morro bay',
#  'eldikan',
#  'wuwei',
#  'bentiu',
#  'kamenskoye',
#  'nabire',
#  'azpeitia',
#  'palafrugell',
#  'mwinilunga',
#  'dinsor',
#  'san gabriel casa blanca',
#  'yagodnoye',
#  'hirara',
#  'gayny',
#  'imbituba',
#  'makakilo city',
#  'kahului',
#  'broome',
#  'saint-joseph',
#  'labuhan',
#  'khandyga',
#  'inhambane',
#  'porto santo',
#  'vestmanna',
#  'fort nelson',
#  'san luis',
#  'vicuna',
#  'saryshagan',
#  'okato',
#  'acajutla',
#  'viksoyri',
#  'wellington',
#  'coos bay',
#  'katete',
#  'anloga',
#  'angoche',
#  'balkanabat',
#  'kondinskoye',
#  'luanda',
#  'deyang',
#  'smirnykh',
#  'kokoda',
#  'saint-francois',
#  'ruatoria',
#  'san juan del sur',
#  'les cayes',
#  'zanatepec',
#  'camacha',
#  'togur',
#  'pelham',
#  'kayerkan',
#  'villena',
#  'sioux lookout',
#  'krasnoye-na-volge',
#  'ngukurr',
#  'kulhudhuffushi',
#  'umm kaddadah',
#  'boa vista',
#  'byron bay',
#  'kochi',
#  'qixingtai',
#  'tarko-sale',
#  'tocopilla',
#  'gat',
#  'breves',
#  'belaya gora',
#  'santa cruz',
#  'bereda',
#  'novosokolniki',
#  'palembang',
#  'rawson',
#  'semirom',
#  'wewak',
#  'los llanos de aridane',
#  'touba',
#  'shenjiamen',
#  'miri',
#  'nizhniy chir',
#  'balancan',
#  'muzaffarabad',
#  'sovetskaya gavan',
#  'panaba',
#  'katobu',
#  'jurm',
#  'talnakh',
#  'pirapozinho',
#  'gopalur',
#  'teguise',
#  'toliary',
#  'amapa',
#  'matamoros',
#  'marawi',
#  'chagda',
#  'great bend',
#  'nioro',
#  'aljezur',
#  'rio gallegos',
#  'laurel',
#  'mullaitivu',
#  'klaksvik',
#  'chirilagua',
#  'grimshaw',
#  'sanchor',
#  'pacifica',
#  'lata',
#  'taltal',
#  'izhma',
#  'multai',
#  'the valley',
#  'dingle',
#  'pyay',
#  'leningradskiy',
#  'parainen',
#  'launceston',
#  'saint-leu',
#  'tautira',
#  'khani',
#  'gobabis',
#  'mahajanga',
#  'mayor pablo lagerenza',
#  'tambura',
#  'siguiri',
#  'jalapa',
#  'muroto',
#  'viedma',
#  'hobyo',
#  'ancud',
#  'santa rosa',
#  'tecolutla',
#  'puerto narino',
#  'astana',
#  'cayeli',
#  'broken hill',
#  'contamana',
#  'karaul',
#  'nador',
#  'dandong',
#  'dobroye',
#  'manzil salim',
#  'mayo',
#  'kon tum',
#  'ushtobe',
#  'kouroussa',
#  'ubinskoye',
#  'jvari',
#  'siloam springs',
#  'meyungs',
#  'kholtoson',
#  'krasnaya gorka',
#  'port keats',
#  'jarvenpaa',
#  'barcelos',
#  'beregovoy',
#  'thaba nchu',
#  'zatoka',
#  'wanlaweyn',
#  'grand-santi',
#  'naryan-mar',
#  'grand island',
#  'xuddur',
#  'san andres',
#  'bay roberts',
#  'yaan',
#  'saint george',
#  'aleksandrovka',
#  'coracora',
#  'tura',
#  'san jose',
#  'svetlyy',
#  'sorvag',
#  'yanan',
#  'soyo',
#  'tromso',
#  'plock',
#  'bakchar',
#  'hambantota',
#  'pandan',
#  'lemesos',
#  'kawalu',
#  'suzu',
#  'monrovia',
#  'gladstone',
#  'virginia beach',
#  'havelock',
#  'teya',
#  'semenyih',
#  'mitu',
#  'chadiza',
#  'slave lake',
#  'saint-georges',
#  'kieta',
#  'zhoucheng',
#  'lasa',
#  'alofi',
#  'fort saint john',
#  'black river',
#  'erenhot',
#  'manjacaze',
#  'champerico',
#  'senno',
#  'riohacha',
#  'mumbwa',
#  'korla',
#  'bilibino',
#  'knysna',
#  'dubasari',
#  'sivas',
#  'waw',
#  'roald',
#  'kampot',
#  'port hardy',
#  'angouleme',
#  'zemio',
#  'marsh harbour',
#  'tawkar',
#  'northam',
#  'shuangyang',
#  'malchevskaya',
#  'sofiysk',
#  'hohhot',
#  'waspan',
#  'bhavnagar',
#  'rongcheng',
#  'tibati',
#  'bhattiprolu',
#  'sidi ali',
#  'pudozh',
#  'kutum',
#  'berdigestyakh',
#  'pooler',
#  'trincomalee',
#  'izoplit',
#  'sinkat',
#  'mukhen',
#  'belmonte',
#  'dryden',
#  'challans',
#  'polson',
#  'conceicao do araguaia',
#  'paka',
#  'cap-aux-meules',
#  'vanavara',
#  'dauphin',
#  'manta',
#  'batagay-alyta',
#  'ivangorod',
#  'traverse city',
#  'atbasar',
#  'manaus',
#  'chunskiy',
#  'shelburne',
#  'cam pha',
#  'bandarban',
#  'oktyabrskiy',
#  'zhetybay',
#  'okhotsk',
#  'yarmouth',
#  'sandovo',
#  'milford',
#  'port-cartier',
#  'verkhnyaya toyma',
#  'karakol',
#  'mopipi',
#  'bojonegoro',
#  'awbari',
#  'dioknisi',
#  'portland',
#  'mecca']

# %%
enumerate(cities)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = len(cities)


url="http://api.openweathermap.org/data/2.5/weather"

params={
    "units":"imperial",
    "appid":weather_api_key,
    "q":""
}


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Create endpoint URL with each city.
    params["q"] = city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(url, params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dscr = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date,
                          "Current Description": city_weather_dscr
                         })

# If an error is experienced, skip the city.
    except Exception as inst:
        print("City not found. Skipping..." + str(inst))
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 737 | ponta do sol
# City not found. Skipping...'coord'
# Processing Record 2 of Set 737 | baruun-urt
# Processing Record 3 of Set 737 | belyy yar
# City not found. Skipping...'coord'
# Processing Record 4 of Set 737 | cape town
# City not found. Skipping...'coord'
# Processing Record 5 of Set 737 | saint-philippe
# Processing Record 6 of Set 737 | bambous virieux
# City not found. Skipping...'coord'
# Processing Record 7 of Set 737 | hay river
# City not found. Skipping...'coord'
# Processing Record 8 of Set 737 | busselton
# Processing Record 9 of Set 737 | kaitangata
# Processing Record 10 of Set 737 | ushuaia
# Processing Record 11 of Set 737 | haines junction
# City not found. Skipping...'coord'
# Processing Record 12 of Set 737 | clyde river
# City not found. Skipping...'coord'
# Processing Record 13 of Set 737 | punta arenas
# City not found. Skipping...'coord'
# Processing Record 14 of Set 737 | constitucion
# Processing Record 15 of Set 737 | sao filipe
# City not found. Skipping...'coord'
# Processing Record 16 of Set 737 | jamestown
# Processing Record 17 of Set 737 | asyut
# Processing Record 18 of Set 737 | esperance
# Processing Record 19 of Set 737 | albany
# Processing Record 20 of Set 737 | castro
# Processing Record 21 of Set 737 | westport
# Processing Record 22 of Set 737 | tuscaloosa
# Processing Record 23 of Set 737 | ulaangom
# Processing Record 24 of Set 737 | waitati
# Processing Record 25 of Set 737 | rikitea
# Processing Record 26 of Set 737 | caravelas
# Processing Record 27 of Set 737 | beringovskiy
# Processing Record 28 of Set 737 | belushya guba
# City not found. Skipping...'coord'
# Processing Record 29 of Set 737 | salalah
# Processing Record 30 of Set 737 | illoqqortoormiut
# City not found. Skipping...'coord'
# Processing Record 31 of Set 737 | lyaskelya
# Processing Record 32 of Set 737 | port elizabeth
# City not found. Skipping...'coord'
# Processing Record 33 of Set 737 | hobart
# Processing Record 34 of Set 737 | taolanaro
# City not found. Skipping...'coord'
# Processing Record 35 of Set 737 | mahanoro
# Processing Record 36 of Set 737 | bredasdorp
# Processing Record 37 of Set 737 | bargur
# Processing Record 38 of Set 737 | bonthe
# Processing Record 39 of Set 737 | tasiilaq
# Processing Record 40 of Set 737 | barrow
# Processing Record 41 of Set 737 | vila velha
# City not found. Skipping...'coord'
# Processing Record 42 of Set 737 | mar del plata
# City not found. Skipping...'coord'
# Processing Record 43 of Set 737 | lolua
# City not found. Skipping...'coord'
# Processing Record 44 of Set 737 | hilo
# Processing Record 45 of Set 737 | bafra
# Processing Record 46 of Set 737 | sibolga
# Processing Record 47 of Set 737 | victoria
# Processing Record 48 of Set 737 | kalmunai
# Processing Record 49 of Set 737 | dikson
# Processing Record 50 of Set 737 | yaring
# Processing Record 51 of Set 737 | vaini
# Processing Record 52 of Set 737 | graaff-reinet
# Processing Record 53 of Set 737 | luau
# Processing Record 54 of Set 737 | khatanga
# Processing Record 55 of Set 737 | hami
# Processing Record 56 of Set 737 | manzhouli
# Processing Record 57 of Set 737 | dashitou
# Processing Record 58 of Set 737 | tiksi
# Processing Record 59 of Set 737 | nanakuli
# Processing Record 60 of Set 737 | chuy
# Processing Record 61 of Set 737 | muros
# Processing Record 62 of Set 737 | katsuura
# Processing Record 63 of Set 737 | san quintin
# City not found. Skipping...'coord'
# Processing Record 64 of Set 737 | pangnirtung
# Processing Record 65 of Set 737 | mys shmidta
# City not found. Skipping...'coord'
# Processing Record 66 of Set 737 | plettenberg bay
# City not found. Skipping...'coord'
# Processing Record 67 of Set 737 | batagay
# Processing Record 68 of Set 737 | kapaa
# Processing Record 69 of Set 737 | marcona
# City not found. Skipping...'coord'
# Processing Record 70 of Set 737 | hermanus
# Processing Record 71 of Set 737 | hithadhoo
# Processing Record 72 of Set 737 | bathsheba
# Processing Record 73 of Set 737 | port lincoln
# City not found. Skipping...'coord'
# Processing Record 74 of Set 737 | bilma
# Processing Record 75 of Set 737 | cabo san lucas
# City not found. Skipping...'coord'
# Processing Record 76 of Set 737 | arraial do cabo
# City not found. Skipping...'coord'
# Processing Record 77 of Set 737 | half moon bay
# City not found. Skipping...'coord'
# Processing Record 78 of Set 737 | itaituba
# Processing Record 79 of Set 737 | qaqortoq
# Processing Record 80 of Set 737 | petauke
# Processing Record 81 of Set 737 | tuatapere
# Processing Record 82 of Set 737 | monroe
# Processing Record 83 of Set 737 | georgetown
# Processing Record 84 of Set 737 | bikin
# Processing Record 85 of Set 737 | grindavik
# Processing Record 86 of Set 737 | port alfred
# City not found. Skipping...'coord'
# Processing Record 87 of Set 737 | butaritari
# Processing Record 88 of Set 737 | nuuk
# Processing Record 89 of Set 737 | eyl
# Processing Record 90 of Set 737 | chokurdakh
# Processing Record 91 of Set 737 | mataura
# Processing Record 92 of Set 737 | auki
# Processing Record 93 of Set 737 | nikolskoye
# Processing Record 94 of Set 737 | arona
# Processing Record 95 of Set 737 | yellowknife
# Processing Record 96 of Set 737 | tuktoyaktuk
# Processing Record 97 of Set 737 | katherine
# Processing Record 98 of Set 737 | vardo
# Processing Record 99 of Set 737 | srednekolymsk
# Processing Record 100 of Set 737 | bambanglipuro
# Processing Record 101 of Set 737 | invermere
# Processing Record 102 of Set 737 | lompoc
# Processing Record 103 of Set 737 | saskylakh
# Processing Record 104 of Set 737 | santiago del estero
# City not found. Skipping...'coord'
# Processing Record 105 of Set 737 | amderma
# City not found. Skipping...'coord'
# Processing Record 106 of Set 737 | iqaluit
# Processing Record 107 of Set 737 | itarema
# Processing Record 108 of Set 737 | zyryanka
# Processing Record 109 of Set 737 | sorong
# Processing Record 110 of Set 737 | kalianget
# Processing Record 111 of Set 737 | buin
# Processing Record 112 of Set 737 | severo-kurilsk
# Processing Record 113 of Set 737 | avarua
# Processing Record 114 of Set 737 | ribeira grande
# City not found. Skipping...'coord'
# Processing Record 115 of Set 737 | souillac
# Processing Record 116 of Set 737 | edd
# Processing Record 117 of Set 737 | vaitupu
# City not found. Skipping...'coord'
# Processing Record 118 of Set 737 | provideniya
# Processing Record 119 of Set 737 | port macquarie
# City not found. Skipping...'coord'
# Processing Record 120 of Set 737 | evensk
# Processing Record 121 of Set 737 | brawley
# Processing Record 122 of Set 737 | upernavik
# Processing Record 123 of Set 737 | aguimes
# Processing Record 124 of Set 737 | barentsburg
# City not found. Skipping...'coord'
# Processing Record 125 of Set 737 | rio grande
# City not found. Skipping...'coord'
# Processing Record 126 of Set 737 | udachnyy
# Processing Record 127 of Set 737 | carnarvon
# Processing Record 128 of Set 737 | mackenzie
# Processing Record 129 of Set 737 | bengkulu
# Processing Record 130 of Set 737 | canutama
# Processing Record 131 of Set 737 | cockburn town
# City not found. Skipping...'coord'
# Processing Record 132 of Set 737 | banjar
# Processing Record 133 of Set 737 | atuona
# Processing Record 134 of Set 737 | dong xoai
# City not found. Skipping...'coord'
# Processing Record 135 of Set 737 | luderitz
# Processing Record 136 of Set 737 | skreia
# Processing Record 137 of Set 737 | nueva loja
# City not found. Skipping...'coord'
# Processing Record 138 of Set 737 | deer lake
# City not found. Skipping...'coord'
# Processing Record 139 of Set 737 | san patricio
# City not found. Skipping...'coord'
# Processing Record 140 of Set 737 | mahebourg
# Processing Record 141 of Set 737 | mehamn
# Processing Record 142 of Set 737 | dossor
# Processing Record 143 of Set 737 | anadyr
# Processing Record 144 of Set 737 | najran
# Processing Record 145 of Set 737 | bethel
# Processing Record 146 of Set 737 | east london
# City not found. Skipping...'coord'
# Processing Record 147 of Set 737 | husavik
# Processing Record 148 of Set 737 | vallenar
# Processing Record 149 of Set 737 | carmarthen
# Processing Record 150 of Set 737 | kodiak
# Processing Record 151 of Set 737 | nanortalik
# Processing Record 152 of Set 737 | gravdal
# Processing Record 153 of Set 737 | thompson
# Processing Record 154 of Set 737 | gazanjyk
# Processing Record 155 of Set 737 | athabasca
# Processing Record 156 of Set 737 | rexburg
# Processing Record 157 of Set 737 | axim
# Processing Record 158 of Set 737 | malkangiri
# Processing Record 159 of Set 737 | henties bay
# City not found. Skipping...'coord'
# Processing Record 160 of Set 737 | doha
# Processing Record 161 of Set 737 | xingyi
# Processing Record 162 of Set 737 | guerrero negro
# City not found. Skipping...'coord'
# Processing Record 163 of Set 737 | goderich
# Processing Record 164 of Set 737 | vila franca do campo
# City not found. Skipping...'coord'
# Processing Record 165 of Set 737 | ilulissat
# Processing Record 166 of Set 737 | paradwip
# City not found. Skipping...'coord'
# Processing Record 167 of Set 737 | kloulklubed
# Processing Record 168 of Set 737 | marrakesh
# Processing Record 169 of Set 737 | linjiang
# Processing Record 170 of Set 737 | isla vista
# City not found. Skipping...'coord'
# Processing Record 171 of Set 737 | umzimvubu
# City not found. Skipping...'coord'
# Processing Record 172 of Set 737 | berlevag
# Processing Record 173 of Set 737 | kyra
# Processing Record 174 of Set 737 | buala
# Processing Record 175 of Set 737 | samarai
# Processing Record 176 of Set 737 | port hawkesbury
# City not found. Skipping...'coord'
# Processing Record 177 of Set 737 | tomohon
# Processing Record 178 of Set 737 | seydi
# Processing Record 179 of Set 737 | aden
# Processing Record 180 of Set 737 | aksu
# Processing Record 181 of Set 737 | faanui
# Processing Record 182 of Set 737 | camopi
# Processing Record 183 of Set 737 | coihaique
# Processing Record 184 of Set 737 | sao domingos
# City not found. Skipping...'coord'
# Processing Record 185 of Set 737 | leh
# Processing Record 186 of Set 737 | yalvac
# Processing Record 187 of Set 737 | asau
# Processing Record 188 of Set 737 | adrar
# Processing Record 189 of Set 737 | marzuq
# Processing Record 190 of Set 737 | cranbrook
# Processing Record 191 of Set 737 | airai
# Processing Record 192 of Set 737 | matara
# Processing Record 193 of Set 737 | aswan
# Processing Record 194 of Set 737 | colgong
# Processing Record 195 of Set 737 | grand gaube
# City not found. Skipping...'coord'
# Processing Record 196 of Set 737 | geraldton
# Processing Record 197 of Set 737 | tsihombe
# City not found. Skipping...'coord'
# Processing Record 198 of Set 737 | baykit
# Processing Record 199 of Set 737 | gornopravdinsk
# Processing Record 200 of Set 737 | mount gambier
# City not found. Skipping...'coord'
# Processing Record 201 of Set 737 | jumla
# Processing Record 202 of Set 737 | ahipara
# Processing Record 203 of Set 737 | ahuimanu
# Processing Record 204 of Set 737 | yangambi
# Processing Record 205 of Set 737 | minot
# Processing Record 206 of Set 737 | presidencia roque saenz pena
# City not found. Skipping...'coord'
# Processing Record 207 of Set 737 | cam ranh
# City not found. Skipping...'coord'
# Processing Record 208 of Set 737 | sambava
# Processing Record 209 of Set 737 | mongoumba
# Processing Record 210 of Set 737 | pucallpa
# Processing Record 211 of Set 737 | lao cai
# City not found. Skipping...'coord'
# Processing Record 212 of Set 737 | puerto ayora
# City not found. Skipping...'coord'
# Processing Record 213 of Set 737 | pisco
# Processing Record 214 of Set 737 | surt
# Processing Record 215 of Set 737 | namibe
# Processing Record 216 of Set 737 | torbay
# Processing Record 217 of Set 737 | nguiu
# City not found. Skipping...'coord'
# Processing Record 218 of Set 737 | carutapera
# Processing Record 219 of Set 737 | saleaula
# City not found. Skipping...'coord'
# Processing Record 220 of Set 737 | agirish
# Processing Record 221 of Set 737 | cayenne
# Processing Record 222 of Set 737 | palmer
# Processing Record 223 of Set 737 | marakkanam
# Processing Record 224 of Set 737 | kununurra
# Processing Record 225 of Set 737 | elat
# Processing Record 226 of Set 737 | cherskiy
# Processing Record 227 of Set 737 | harper
# Processing Record 228 of Set 737 | deputatskiy
# Processing Record 229 of Set 737 | kysyl-syr
# Processing Record 230 of Set 737 | san ignacio
# City not found. Skipping...'coord'
# Processing Record 231 of Set 737 | slavutych
# Processing Record 232 of Set 737 | bluff
# Processing Record 233 of Set 737 | kilindoni
# Processing Record 234 of Set 737 | morant bay
# City not found. Skipping...'coord'
# Processing Record 235 of Set 737 | jackson
# Processing Record 236 of Set 737 | tadine
# Processing Record 237 of Set 737 | aksarka
# Processing Record 238 of Set 737 | alihe
# Processing Record 239 of Set 737 | norman wells
# City not found. Skipping...'coord'
# Processing Record 240 of Set 737 | wagar
# Processing Record 241 of Set 737 | omsukchan
# Processing Record 242 of Set 737 | ambovombe
# Processing Record 243 of Set 737 | gainesville
# Processing Record 244 of Set 737 | huehuetan
# Processing Record 245 of Set 737 | qaanaaq
# Processing Record 246 of Set 737 | ola
# Processing Record 247 of Set 737 | zhigansk
# Processing Record 248 of Set 737 | ondorhaan
# City not found. Skipping...'coord'
# Processing Record 249 of Set 737 | naze
# Processing Record 250 of Set 737 | guia de isora
# City not found. Skipping...'coord'
# Processing Record 251 of Set 737 | hare bay
# City not found. Skipping...'coord'
# Processing Record 252 of Set 737 | gamba
# Processing Record 253 of Set 737 | esso
# Processing Record 254 of Set 737 | falealupo
# City not found. Skipping...'coord'
# Processing Record 255 of Set 737 | ust-kulom
# Processing Record 256 of Set 737 | aklavik
# Processing Record 257 of Set 737 | korostyshiv
# Processing Record 258 of Set 737 | krasnoselkup
# Processing Record 259 of Set 737 | rena
# Processing Record 260 of Set 737 | lagoa
# Processing Record 261 of Set 737 | new norfolk
# City not found. Skipping...'coord'
# Processing Record 262 of Set 737 | quatre cocos
# City not found. Skipping...'coord'
# Processing Record 263 of Set 737 | conde
# Processing Record 264 of Set 737 | talara
# Processing Record 265 of Set 737 | ambilobe
# Processing Record 266 of Set 737 | ambalavao
# Processing Record 267 of Set 737 | chapais
# Processing Record 268 of Set 737 | bundaberg
# Processing Record 269 of Set 737 | maniitsoq
# Processing Record 270 of Set 737 | san cristobal
# City not found. Skipping...'coord'
# Processing Record 271 of Set 737 | kavieng
# Processing Record 272 of Set 737 | bowen
# Processing Record 273 of Set 737 | calvinia
# Processing Record 274 of Set 737 | flin flon
# City not found. Skipping...'coord'
# Processing Record 275 of Set 737 | fukuchiyama
# Processing Record 276 of Set 737 | lebu
# Processing Record 277 of Set 737 | tumannyy
# City not found. Skipping...'coord'
# Processing Record 278 of Set 737 | huntington
# Processing Record 279 of Set 737 | bridlington
# Processing Record 280 of Set 737 | sur
# Processing Record 281 of Set 737 | bayan
# Processing Record 282 of Set 737 | aubenas
# Processing Record 283 of Set 737 | bayanday
# Processing Record 284 of Set 737 | codrington
# Processing Record 285 of Set 737 | iskateley
# Processing Record 286 of Set 737 | lima
# Processing Record 287 of Set 737 | seeboden
# Processing Record 288 of Set 737 | lisala
# Processing Record 289 of Set 737 | lodja
# Processing Record 290 of Set 737 | el cobre
# City not found. Skipping...'coord'
# Processing Record 291 of Set 737 | arlit
# Processing Record 292 of Set 737 | jalu
# Processing Record 293 of Set 737 | alice springs
# City not found. Skipping...'coord'
# Processing Record 294 of Set 737 | attawapiskat
# City not found. Skipping...'coord'
# Processing Record 295 of Set 737 | bargal
# City not found. Skipping...'coord'
# Processing Record 296 of Set 737 | bonavista
# Processing Record 297 of Set 737 | uhlove
# Processing Record 298 of Set 737 | mongo
# Processing Record 299 of Set 737 | mount isa
# City not found. Skipping...'coord'
# Processing Record 300 of Set 737 | morondava
# Processing Record 301 of Set 737 | ler
# Processing Record 302 of Set 737 | cabo rojo
# City not found. Skipping...'coord'
# Processing Record 303 of Set 737 | vao
# Processing Record 304 of Set 737 | sisimiut
# Processing Record 305 of Set 737 | biak
# Processing Record 306 of Set 737 | porosozero
# Processing Record 307 of Set 737 | avera
# Processing Record 308 of Set 737 | kushima
# Processing Record 309 of Set 737 | dunedin
# Processing Record 310 of Set 737 | texarkana
# Processing Record 311 of Set 737 | antalaha
# Processing Record 312 of Set 737 | aloleng
# Processing Record 313 of Set 737 | vreed en hoop
# City not found. Skipping...'coord'
# Processing Record 314 of Set 737 | am timan
# City not found. Skipping...'coord'
# Processing Record 315 of Set 737 | palabuhanratu
# City not found. Skipping...'coord'
# Processing Record 316 of Set 737 | artyk
# City not found. Skipping...'coord'
# Processing Record 317 of Set 737 | karkaralinsk
# City not found. Skipping...'coord'
# Processing Record 318 of Set 737 | petropavlovsk-kamchatskiy
# Processing Record 319 of Set 737 | yataity
# Processing Record 320 of Set 737 | gujan-mestras
# Processing Record 321 of Set 737 | kavaratti
# Processing Record 322 of Set 737 | yerbogachen
# Processing Record 323 of Set 737 | yulara
# Processing Record 324 of Set 737 | mudgee
# Processing Record 325 of Set 737 | touros
# Processing Record 326 of Set 737 | korhogo
# Processing Record 327 of Set 737 | julio de castilhos
# City not found. Skipping...'coord'
# Processing Record 328 of Set 737 | padang
# Processing Record 329 of Set 737 | acarau
# Processing Record 330 of Set 737 | shingu
# Processing Record 331 of Set 737 | janakpur road
# City not found. Skipping...'coord'
# Processing Record 332 of Set 737 | kuche
# City not found. Skipping...'coord'
# Processing Record 333 of Set 737 | kozhevnikovo
# Processing Record 334 of Set 737 | carbonia
# Processing Record 335 of Set 737 | atar
# Processing Record 336 of Set 737 | chirongui
# Processing Record 337 of Set 737 | bukit rambai
# City not found. Skipping...'coord'
# Processing Record 338 of Set 737 | green valley
# City not found. Skipping...'coord'
# Processing Record 339 of Set 737 | eureka
# Processing Record 340 of Set 737 | hamilton
# Processing Record 341 of Set 737 | houma
# Processing Record 342 of Set 737 | quang ngai
# City not found. Skipping...'coord'
# Processing Record 343 of Set 737 | el sauzal
# City not found. Skipping...'coord'
# Processing Record 344 of Set 737 | hasaki
# Processing Record 345 of Set 737 | villamontes
# Processing Record 346 of Set 737 | ranong
# Processing Record 347 of Set 737 | luang prabang
# City not found. Skipping...'coord'
# Processing Record 348 of Set 737 | komsomolskiy
# Processing Record 349 of Set 737 | verkhoyansk
# Processing Record 350 of Set 737 | qeshm
# Processing Record 351 of Set 737 | ketchikan
# Processing Record 352 of Set 737 | kruisfontein
# Processing Record 353 of Set 737 | nizhniy kuranakh
# City not found. Skipping...'coord'
# Processing Record 354 of Set 737 | charleston
# Processing Record 355 of Set 737 | tommot
# Processing Record 356 of Set 737 | fairbanks
# Processing Record 357 of Set 737 | allapalli
# Processing Record 358 of Set 737 | royan
# Processing Record 359 of Set 737 | pirovskoye
# Processing Record 360 of Set 737 | saurimo
# Processing Record 361 of Set 737 | lorengau
# Processing Record 362 of Set 737 | saldanha
# Processing Record 363 of Set 737 | coquimbo
# Processing Record 364 of Set 737 | bacuit
# City not found. Skipping...'coord'
# Processing Record 365 of Set 737 | nemuro
# Processing Record 366 of Set 737 | arimalam
# Processing Record 367 of Set 737 | umm durman
# City not found. Skipping...'coord'
# Processing Record 368 of Set 737 | kanniyakumari
# Processing Record 369 of Set 737 | bougouni
# Processing Record 370 of Set 737 | pishin
# Processing Record 371 of Set 737 | pailon
# Processing Record 372 of Set 737 | sirjan
# Processing Record 373 of Set 737 | warqla
# City not found. Skipping...'coord'
# Processing Record 374 of Set 737 | dumas
# Processing Record 375 of Set 737 | rungata
# City not found. Skipping...'coord'
# Processing Record 376 of Set 737 | magadan
# Processing Record 377 of Set 737 | madeji
# Processing Record 378 of Set 737 | nome
# Processing Record 379 of Set 737 | neenah
# Processing Record 380 of Set 737 | fukuma
# Processing Record 381 of Set 737 | uromi
# Processing Record 382 of Set 737 | cidreira
# Processing Record 383 of Set 737 | grande prairie
# City not found. Skipping...'coord'
# Processing Record 384 of Set 737 | acapulco
# Processing Record 385 of Set 737 | narsaq
# Processing Record 386 of Set 737 | tessalit
# Processing Record 387 of Set 737 | severobaykalsk
# Processing Record 388 of Set 737 | jambi
# Processing Record 389 of Set 737 | fairlie
# Processing Record 390 of Set 737 | la ronge
# City not found. Skipping...'coord'
# Processing Record 391 of Set 737 | rodrigues alves
# City not found. Skipping...'coord'
# Processing Record 392 of Set 737 | ixtapa
# Processing Record 393 of Set 737 | huilong
# Processing Record 394 of Set 737 | varkkallai
# Processing Record 395 of Set 737 | ostrovnoy
# Processing Record 396 of Set 737 | buraydah
# Processing Record 397 of Set 737 | constantine
# Processing Record 398 of Set 737 | bukama
# Processing Record 399 of Set 737 | kirakira
# Processing Record 400 of Set 737 | kommunar
# Processing Record 401 of Set 737 | necochea
# Processing Record 402 of Set 737 | sukumo
# Processing Record 403 of Set 737 | sorland
# Processing Record 404 of Set 737 | longyearbyen
# Processing Record 405 of Set 737 | karratha
# Processing Record 406 of Set 737 | vorobyevka
# Processing Record 407 of Set 737 | bandar-e torkaman
# City not found. Skipping...'coord'
# Processing Record 408 of Set 737 | novoagansk
# Processing Record 409 of Set 737 | valparaiso
# Processing Record 410 of Set 737 | phalaborwa
# Processing Record 411 of Set 737 | igarka
# Processing Record 412 of Set 737 | fortuna
# Processing Record 413 of Set 737 | tahoua
# Processing Record 414 of Set 737 | west wendover
# City not found. Skipping...'coord'
# Processing Record 415 of Set 737 | asfi
# Processing Record 416 of Set 737 | issoudun
# Processing Record 417 of Set 737 | xining
# Processing Record 418 of Set 737 | lyubar
# Processing Record 419 of Set 737 | klamath falls
# City not found. Skipping...'coord'
# Processing Record 420 of Set 737 | tugalan
# City not found. Skipping...'coord'
# Processing Record 421 of Set 737 | natal
# Processing Record 422 of Set 737 | sentyabrskiy
# City not found. Skipping...'coord'
# Processing Record 423 of Set 737 | siocon
# Processing Record 424 of Set 737 | buchanan
# Processing Record 425 of Set 737 | tezu
# Processing Record 426 of Set 737 | olafsvik
# Processing Record 427 of Set 737 | waipawa
# Processing Record 428 of Set 737 | goundam
# Processing Record 429 of Set 737 | kokopo
# Processing Record 430 of Set 737 | mitsamiouli
# Processing Record 431 of Set 737 | skibbereen
# Processing Record 432 of Set 737 | nizhneyansk
# City not found. Skipping...'coord'
# Processing Record 433 of Set 737 | walvis bay
# City not found. Skipping...'coord'
# Processing Record 434 of Set 737 | rafai
# Processing Record 435 of Set 737 | sao joao da barra
# City not found. Skipping...'coord'
# Processing Record 436 of Set 737 | samusu
# City not found. Skipping...'coord'
# Processing Record 437 of Set 737 | vangaindrano
# Processing Record 438 of Set 737 | isangel
# Processing Record 439 of Set 737 | santa vitoria do palmar
# City not found. Skipping...'coord'
# Processing Record 440 of Set 737 | sitka
# Processing Record 441 of Set 737 | potgietersrus
# City not found. Skipping...'coord'
# Processing Record 442 of Set 737 | ugoofaaru
# Processing Record 443 of Set 737 | santarem
# Processing Record 444 of Set 737 | pasni
# Processing Record 445 of Set 737 | pimenteiras
# Processing Record 446 of Set 737 | paamiut
# Processing Record 447 of Set 737 | taoudenni
# Processing Record 448 of Set 737 | seinajoki
# Processing Record 449 of Set 737 | pevek
# Processing Record 450 of Set 737 | hofn
# Processing Record 451 of Set 737 | farkhor
# Processing Record 452 of Set 737 | otane
# Processing Record 453 of Set 737 | griffith
# Processing Record 454 of Set 737 | wasilla
# Processing Record 455 of Set 737 | aksehir
# Processing Record 456 of Set 737 | richards bay
# City not found. Skipping...'coord'
# Processing Record 457 of Set 737 | dali
# Processing Record 458 of Set 737 | sechura
# Processing Record 459 of Set 737 | strezhevoy
# Processing Record 460 of Set 737 | sandy bay
# City not found. Skipping...'coord'
# Processing Record 461 of Set 737 | pangkalanbuun
# Processing Record 462 of Set 737 | port hedland
# City not found. Skipping...'coord'
# Processing Record 463 of Set 737 | yumen
# Processing Record 464 of Set 737 | grand river south east
# City not found. Skipping...'coord'
# Processing Record 465 of Set 737 | talbahat
# Processing Record 466 of Set 737 | flinders
# Processing Record 467 of Set 737 | sapele
# Processing Record 468 of Set 737 | tuggurt
# City not found. Skipping...'coord'
# Processing Record 469 of Set 737 | pangody
# Processing Record 470 of Set 737 | morro bay
# City not found. Skipping...'coord'
# Processing Record 471 of Set 737 | eldikan
# City not found. Skipping...'coord'
# Processing Record 472 of Set 737 | wuwei
# Processing Record 473 of Set 737 | bentiu
# Processing Record 474 of Set 737 | kamenskoye
# City not found. Skipping...'coord'
# Processing Record 475 of Set 737 | nabire
# Processing Record 476 of Set 737 | azpeitia
# Processing Record 477 of Set 737 | palafrugell
# Processing Record 478 of Set 737 | mwinilunga
# Processing Record 479 of Set 737 | dinsor
# City not found. Skipping...'coord'
# Processing Record 480 of Set 737 | san gabriel casa blanca
# City not found. Skipping...'coord'
# Processing Record 481 of Set 737 | yagodnoye
# Processing Record 482 of Set 737 | hirara
# Processing Record 483 of Set 737 | gayny
# Processing Record 484 of Set 737 | imbituba
# Processing Record 485 of Set 737 | makakilo city
# City not found. Skipping...'coord'
# Processing Record 486 of Set 737 | kahului
# Processing Record 487 of Set 737 | broome
# Processing Record 488 of Set 737 | saint-joseph
# Processing Record 489 of Set 737 | labuhan
# Processing Record 490 of Set 737 | khandyga
# Processing Record 491 of Set 737 | inhambane
# Processing Record 492 of Set 737 | porto santo
# City not found. Skipping...'coord'
# Processing Record 493 of Set 737 | vestmanna
# Processing Record 494 of Set 737 | fort nelson
# City not found. Skipping...'coord'
# Processing Record 495 of Set 737 | san luis
# City not found. Skipping...'coord'
# Processing Record 496 of Set 737 | vicuna
# Processing Record 497 of Set 737 | saryshagan
# City not found. Skipping...'coord'
# Processing Record 498 of Set 737 | okato
# Processing Record 499 of Set 737 | acajutla
# Processing Record 500 of Set 737 | viksoyri
# City not found. Skipping...'coord'
# Processing Record 501 of Set 737 | wellington
# Processing Record 502 of Set 737 | coos bay
# City not found. Skipping...'coord'
# Processing Record 503 of Set 737 | katete
# Processing Record 504 of Set 737 | anloga
# Processing Record 505 of Set 737 | angoche
# Processing Record 506 of Set 737 | balkanabat
# Processing Record 507 of Set 737 | kondinskoye
# Processing Record 508 of Set 737 | luanda
# Processing Record 509 of Set 737 | deyang
# Processing Record 510 of Set 737 | smirnykh
# Processing Record 511 of Set 737 | kokoda
# Processing Record 512 of Set 737 | saint-francois
# Processing Record 513 of Set 737 | ruatoria
# City not found. Skipping...'coord'
# Processing Record 514 of Set 737 | san juan del sur
# City not found. Skipping...'coord'
# Processing Record 515 of Set 737 | les cayes
# City not found. Skipping...'coord'
# Processing Record 516 of Set 737 | zanatepec
# City not found. Skipping...'coord'
# Processing Record 517 of Set 737 | camacha
# Processing Record 518 of Set 737 | togur
# Processing Record 519 of Set 737 | pelham
# Processing Record 520 of Set 737 | kayerkan
# Processing Record 521 of Set 737 | villena
# Processing Record 522 of Set 737 | sioux lookout
# City not found. Skipping...'coord'
# Processing Record 523 of Set 737 | krasnoye-na-volge
# Processing Record 524 of Set 737 | ngukurr
# City not found. Skipping...'coord'
# Processing Record 525 of Set 737 | kulhudhuffushi
# Processing Record 526 of Set 737 | umm kaddadah
# City not found. Skipping...'coord'
# Processing Record 527 of Set 737 | boa vista
# City not found. Skipping...'coord'
# Processing Record 528 of Set 737 | byron bay
# City not found. Skipping...'coord'
# Processing Record 529 of Set 737 | kochi
# Processing Record 530 of Set 737 | qixingtai
# Processing Record 531 of Set 737 | tarko-sale
# Processing Record 532 of Set 737 | tocopilla
# Processing Record 533 of Set 737 | gat
# Processing Record 534 of Set 737 | breves
# Processing Record 535 of Set 737 | belaya gora
# City not found. Skipping...'coord'
# Processing Record 536 of Set 737 | santa cruz
# City not found. Skipping...'coord'
# Processing Record 537 of Set 737 | bereda
# Processing Record 538 of Set 737 | novosokolniki
# Processing Record 539 of Set 737 | palembang
# Processing Record 540 of Set 737 | rawson
# Processing Record 541 of Set 737 | semirom
# Processing Record 542 of Set 737 | wewak
# Processing Record 543 of Set 737 | los llanos de aridane
# City not found. Skipping...'coord'
# Processing Record 544 of Set 737 | touba
# Processing Record 545 of Set 737 | shenjiamen
# Processing Record 546 of Set 737 | miri
# Processing Record 547 of Set 737 | nizhniy chir
# City not found. Skipping...'coord'
# Processing Record 548 of Set 737 | balancan
# Processing Record 549 of Set 737 | muzaffarabad
# Processing Record 550 of Set 737 | sovetskaya gavan
# City not found. Skipping...'coord'
# Processing Record 551 of Set 737 | panaba
# Processing Record 552 of Set 737 | katobu
# Processing Record 553 of Set 737 | jurm
# Processing Record 554 of Set 737 | talnakh
# Processing Record 555 of Set 737 | pirapozinho
# Processing Record 556 of Set 737 | gopalur
# Processing Record 557 of Set 737 | teguise
# Processing Record 558 of Set 737 | toliary
# City not found. Skipping...'coord'
# Processing Record 559 of Set 737 | amapa
# Processing Record 560 of Set 737 | matamoros
# Processing Record 561 of Set 737 | marawi
# Processing Record 562 of Set 737 | chagda
# City not found. Skipping...'coord'
# Processing Record 563 of Set 737 | great bend
# City not found. Skipping...'coord'
# Processing Record 564 of Set 737 | nioro
# Processing Record 565 of Set 737 | aljezur
# Processing Record 566 of Set 737 | rio gallegos
# City not found. Skipping...'coord'
# Processing Record 567 of Set 737 | laurel
# Processing Record 568 of Set 737 | mullaitivu
# City not found. Skipping...'coord'
# Processing Record 569 of Set 737 | klaksvik
# Processing Record 570 of Set 737 | chirilagua
# Processing Record 571 of Set 737 | grimshaw
# Processing Record 572 of Set 737 | sanchor
# Processing Record 573 of Set 737 | pacifica
# Processing Record 574 of Set 737 | lata
# Processing Record 575 of Set 737 | taltal
# Processing Record 576 of Set 737 | izhma
# Processing Record 577 of Set 737 | multai
# Processing Record 578 of Set 737 | the valley
# City not found. Skipping...'coord'
# Processing Record 579 of Set 737 | dingle
# Processing Record 580 of Set 737 | pyay
# Processing Record 581 of Set 737 | leningradskiy
# Processing Record 582 of Set 737 | parainen
# Processing Record 583 of Set 737 | launceston
# Processing Record 584 of Set 737 | saint-leu
# Processing Record 585 of Set 737 | tautira
# Processing Record 586 of Set 737 | khani
# Processing Record 587 of Set 737 | gobabis
# Processing Record 588 of Set 737 | mahajanga
# Processing Record 589 of Set 737 | mayor pablo lagerenza
# City not found. Skipping...'coord'
# Processing Record 590 of Set 737 | tambura
# Processing Record 591 of Set 737 | siguiri
# Processing Record 592 of Set 737 | jalapa
# Processing Record 593 of Set 737 | muroto
# Processing Record 594 of Set 737 | viedma
# Processing Record 595 of Set 737 | hobyo
# Processing Record 596 of Set 737 | ancud
# Processing Record 597 of Set 737 | santa rosa
# City not found. Skipping...'coord'
# Processing Record 598 of Set 737 | tecolutla
# Processing Record 599 of Set 737 | puerto narino
# City not found. Skipping...'coord'
# Processing Record 600 of Set 737 | astana
# Processing Record 601 of Set 737 | cayeli
# Processing Record 602 of Set 737 | broken hill
# City not found. Skipping...'coord'
# Processing Record 603 of Set 737 | contamana
# Processing Record 604 of Set 737 | karaul
# City not found. Skipping...'coord'
# Processing Record 605 of Set 737 | nador
# Processing Record 606 of Set 737 | dandong
# Processing Record 607 of Set 737 | dobroye
# Processing Record 608 of Set 737 | manzil salim
# City not found. Skipping...'coord'
# Processing Record 609 of Set 737 | mayo
# Processing Record 610 of Set 737 | kon tum
# City not found. Skipping...'coord'
# Processing Record 611 of Set 737 | ushtobe
# Processing Record 612 of Set 737 | kouroussa
# Processing Record 613 of Set 737 | ubinskoye
# Processing Record 614 of Set 737 | jvari
# Processing Record 615 of Set 737 | siloam springs
# City not found. Skipping...'coord'
# Processing Record 616 of Set 737 | meyungs
# City not found. Skipping...'coord'
# Processing Record 617 of Set 737 | kholtoson
# Processing Record 618 of Set 737 | krasnaya gorka
# City not found. Skipping...'coord'
# Processing Record 619 of Set 737 | port keats
# City not found. Skipping...'coord'
# Processing Record 620 of Set 737 | jarvenpaa
# Processing Record 621 of Set 737 | barcelos
# Processing Record 622 of Set 737 | beregovoy
# Processing Record 623 of Set 737 | thaba nchu
# City not found. Skipping...'coord'
# Processing Record 624 of Set 737 | zatoka
# Processing Record 625 of Set 737 | wanlaweyn
# Processing Record 626 of Set 737 | grand-santi
# Processing Record 627 of Set 737 | naryan-mar
# Processing Record 628 of Set 737 | grand island
# City not found. Skipping...'coord'
# Processing Record 629 of Set 737 | xuddur
# Processing Record 630 of Set 737 | san andres
# City not found. Skipping...'coord'
# Processing Record 631 of Set 737 | bay roberts
# City not found. Skipping...'coord'
# Processing Record 632 of Set 737 | yaan
# Processing Record 633 of Set 737 | saint george
# City not found. Skipping...'coord'
# Processing Record 634 of Set 737 | aleksandrovka
# Processing Record 635 of Set 737 | coracora
# Processing Record 636 of Set 737 | tura
# Processing Record 637 of Set 737 | san jose
# City not found. Skipping...'coord'
# Processing Record 638 of Set 737 | svetlyy
# Processing Record 639 of Set 737 | sorvag
# City not found. Skipping...'coord'
# Processing Record 640 of Set 737 | yanan
# City not found. Skipping...'coord'
# Processing Record 641 of Set 737 | soyo
# Processing Record 642 of Set 737 | tromso
# Processing Record 643 of Set 737 | plock
# Processing Record 644 of Set 737 | bakchar
# Processing Record 645 of Set 737 | hambantota
# Processing Record 646 of Set 737 | pandan
# Processing Record 647 of Set 737 | lemesos
# City not found. Skipping...'coord'
# Processing Record 648 of Set 737 | kawalu
# Processing Record 649 of Set 737 | suzu
# City not found. Skipping...'coord'
# Processing Record 650 of Set 737 | monrovia
# Processing Record 651 of Set 737 | gladstone
# Processing Record 652 of Set 737 | virginia beach
# City not found. Skipping...'coord'
# Processing Record 653 of Set 737 | havelock
# Processing Record 654 of Set 737 | teya
# Processing Record 655 of Set 737 | semenyih
# Processing Record 656 of Set 737 | mitu
# Processing Record 657 of Set 737 | chadiza
# Processing Record 658 of Set 737 | slave lake
# City not found. Skipping...'coord'
# Processing Record 659 of Set 737 | saint-georges
# Processing Record 660 of Set 737 | kieta
# Processing Record 661 of Set 737 | zhoucheng
# Processing Record 662 of Set 737 | lasa
# Processing Record 663 of Set 737 | alofi
# Processing Record 664 of Set 737 | fort saint john
# City not found. Skipping...'coord'
# Processing Record 665 of Set 737 | black river
# City not found. Skipping...'coord'
# Processing Record 666 of Set 737 | erenhot
# Processing Record 667 of Set 737 | manjacaze
# Processing Record 668 of Set 737 | champerico
# Processing Record 669 of Set 737 | senno
# Processing Record 670 of Set 737 | riohacha
# Processing Record 671 of Set 737 | mumbwa
# Processing Record 672 of Set 737 | korla
# Processing Record 673 of Set 737 | bilibino
# Processing Record 674 of Set 737 | knysna
# Processing Record 675 of Set 737 | dubasari
# Processing Record 676 of Set 737 | sivas
# Processing Record 677 of Set 737 | waw
# Processing Record 678 of Set 737 | roald
# Processing Record 679 of Set 737 | kampot
# Processing Record 680 of Set 737 | port hardy
# City not found. Skipping...'coord'
# Processing Record 681 of Set 737 | angouleme
# Processing Record 682 of Set 737 | zemio
# Processing Record 683 of Set 737 | marsh harbour
# City not found. Skipping...'coord'
# Processing Record 684 of Set 737 | tawkar
# City not found. Skipping...'coord'
# Processing Record 685 of Set 737 | northam
# Processing Record 686 of Set 737 | shuangyang
# Processing Record 687 of Set 737 | malchevskaya
# Processing Record 688 of Set 737 | sofiysk
# City not found. Skipping...'coord'
# Processing Record 689 of Set 737 | hohhot
# Processing Record 690 of Set 737 | waspan
# Processing Record 691 of Set 737 | bhavnagar
# Processing Record 692 of Set 737 | rongcheng
# Processing Record 693 of Set 737 | tibati
# Processing Record 694 of Set 737 | bhattiprolu
# Processing Record 695 of Set 737 | sidi ali
# City not found. Skipping...'coord'
# Processing Record 696 of Set 737 | pudozh
# Processing Record 697 of Set 737 | kutum
# Processing Record 698 of Set 737 | berdigestyakh
# Processing Record 699 of Set 737 | pooler
# Processing Record 700 of Set 737 | trincomalee
# Processing Record 701 of Set 737 | izoplit
# Processing Record 702 of Set 737 | sinkat
# City not found. Skipping...'coord'
# Processing Record 703 of Set 737 | mukhen
# Processing Record 704 of Set 737 | belmonte
# Processing Record 705 of Set 737 | dryden
# Processing Record 706 of Set 737 | challans
# Processing Record 707 of Set 737 | polson
# Processing Record 708 of Set 737 | conceicao do araguaia
# City not found. Skipping...'coord'
# Processing Record 709 of Set 737 | paka
# Processing Record 710 of Set 737 | cap-aux-meules
# Processing Record 711 of Set 737 | vanavara
# Processing Record 712 of Set 737 | dauphin
# Processing Record 713 of Set 737 | manta
# Processing Record 714 of Set 737 | batagay-alyta
# Processing Record 715 of Set 737 | ivangorod
# Processing Record 716 of Set 737 | traverse city
# City not found. Skipping...'coord'
# Processing Record 717 of Set 737 | atbasar
# Processing Record 718 of Set 737 | manaus
# Processing Record 719 of Set 737 | chunskiy
# Processing Record 720 of Set 737 | shelburne
# Processing Record 721 of Set 737 | cam pha
# City not found. Skipping...'coord'
# Processing Record 722 of Set 737 | bandarban
# Processing Record 723 of Set 737 | oktyabrskiy
# Processing Record 724 of Set 737 | zhetybay
# City not found. Skipping...'coord'
# Processing Record 725 of Set 737 | okhotsk
# Processing Record 726 of Set 737 | yarmouth
# Processing Record 727 of Set 737 | sandovo
# Processing Record 728 of Set 737 | milford
# Processing Record 729 of Set 737 | port-cartier
# Processing Record 730 of Set 737 | verkhnyaya toyma
# City not found. Skipping...'coord'
# Processing Record 731 of Set 737 | karakol
# Processing Record 732 of Set 737 | mopipi
# Processing Record 733 of Set 737 | bojonegoro
# Processing Record 734 of Set 737 | awbari
# Processing Record 735 of Set 737 | dioknisi
# Processing Record 736 of Set 737 | portland
# Processing Record 737 of Set 737 | mecca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Baruun-Urt      MN  46.6806  113.2792     74.89        54           0
# 1  Saint-Philippe      RE -21.3585   55.7679     67.59        84          96
# 2       Busselton      AU -33.6500  115.3333     53.04        72          92
# 3      Kaitangata      NZ -46.2817  169.8464     54.93        80          92
# 4         Ushuaia      AR -54.8000  -68.3000     42.46        49           0
# 5    Constitucion      CL -35.3333  -72.4167     51.37        76           0
# 6       Jamestown      US  42.0970  -79.2353     74.52        83          40
# 7           Asyut      EG  27.1810   31.1837     80.78        25          95
# 8       Esperance      AU -33.8667  121.9000     55.24        67          97
# 9          Albany      US  42.6001  -73.9662     70.66        94          92
#
#    Wind Speed                 Date Current Description
# 0        5.79  2021-07-30 01:48:33           clear sky
# 1       15.59  2021-07-30 01:48:34          light rain
# 2       27.04  2021-07-30 01:48:34     overcast clouds
# 3        8.81  2021-07-30 01:48:35     overcast clouds
# 4       10.36  2021-07-30 01:48:35           clear sky
# 5        2.28  2021-07-30 01:48:35           clear sky
# 6        5.57  2021-07-30 01:47:54    scattered clouds
# 7        5.28  2021-07-30 01:45:23     overcast clouds
# 8       26.69  2021-07-30 01:48:36     overcast clouds
# 9        4.68  2021-07-30 01:45:41     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
